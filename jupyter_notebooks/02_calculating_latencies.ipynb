# %% [markdown]
# # MED-PC Calculating Latencies

# %% [markdown]
# ## Importing the Python Libraries

# %%
import sys
import glob
from collections import defaultdict
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from medpc2excel.medpc_read import medpc_read

# %%
# setting path
sys.path.append('../src')

# %%
# All the libraries that were created for this repository
import extract.dataframe
import processing.tone
import extract.metadata

# %%
# Increase size of plot in jupyter

plt.rcParams["figure.figsize"] = (10,6)

# %% [markdown]
# # Loading in Recording and Metadata from Previous Notebook

# %% [markdown]
# # NOTE: If you changed the directory of where the MED-PC recording dataframes, then you must change the directories in the following paths

# %% [markdown]
# - This will get all the files in each specified path

# %%
concatted_medpc_files = glob.glob("./data/extracted_recording_data_and_metadata/*/MEDPC_recording_cage_*.csv")
metadata_files = glob.glob("./data/extracted_recording_data_and_metadata/*/metadata_cage_*.csv")
recording_and_metadata_files = glob.glob("./data/extracted_recording_data_and_metadata/*/recording_and_metadata_cage_*.csv")

# %% [markdown]
# # NOTE: If there is more than one MED-PC recording dataframes, then you must manually change the path in the `pd.read_csv()` for the corresponding variables. Verify if this is the correct file that you want to use

# %%
metadata_files[0]
# Out:
# './data/extracted_recording_data_and_metadata/cage_1_2_3_4_date_20220503_20220516/metadata_cage_1_2_3_4_date_20220503_20220516.csv'

# %%
concatted_medpc_files[0]
# Out:
# './data/extracted_recording_data_and_metadata/cage_1_2_3_4_date_20220503_20220516/MEDPC_recording_cage_1_2_3_4_date_20220503_20220516.csv'

# %%
recording_and_metadata_files[0]
# Out:
# './data/extracted_recording_data_and_metadata/cage_1_2_3_4_date_20220503_20220516/recording_and_metadata_cage_1_2_3_4_date_20220503_20220516.csv'

# %%
metadata_df = pd.read_csv(metadata_files[0], index_col=0)
concatted_medpc_df = pd.read_csv(concatted_medpc_files[0], index_col=0)
recording_and_metadata_df = pd.read_csv(recording_and_metadata_files[0], index_col=0)

# %% [markdown]
# - The Dataframe the contains the metadata(columns) of each recording file(rows)
#     - We will mostly use this to get the cage number for each subject

# %%
metadata_df.head()
# Out:
#                                                index  \
# 0  ./data/timestamp_dataframes/2022-05-06_12h59m_...
# 1  ./data/timestamp_dataframes/2022-05-06_08h37m_...
# 2  ./data/timestamp_dataframes/2022-05-10_14h40m_...
# 3  ./data/timestamp_dataframes/2022-05-06_12h59m_...
# 4  ./data/timestamp_dataframes/2022-05-04_08h43m_...
#
#                                                 File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-05-06_12h59m_Subject 3.4 (...   05/06/22  05/06/22
# 1   C:\MED-PC\Data\2022-05-06_08h37m_Subject 2.3.txt   05/06/22  05/06/22
# 2  C:\MED-PC\Data\2022-05-10_14h40m_Subject 4.3 (...   05/10/22  05/10/22
# 3  C:\MED-PC\Data\2022-05-06_12h59m_Subject 4.3 (...   05/06/22  05/06/22
# 4   C:\MED-PC\Data\2022-05-04_08h43m_Subject 2.3.txt   05/04/22  05/04/22
#
#    Subject      Experiment   Group  Box Start Time  End Time  \
# 0  3.4 (2)  Pilot of Pilot  Cage 4    1   12:59:58  14:02:38
# 1      2.3  Pilot of Pilot  Cage 1    1   08:37:09  09:53:25
# 2  4.3 (3)  Pilot of Pilot  Cage 4    2   14:40:24  15:43:18
# 3  4.3 (3)  Pilot of Pilot  Cage 4    2   12:59:58  14:02:38
# 4      2.3  Pilot of Pilot  Cage 1    3   08:43:11  09:54:22
#
#                                          MSN  cage
# 0  levelNP_CS_reward_laserepochON1st_noshock   4.0
# 1  levelNP_CS_reward_laserepochON1st_noshock   1.0
# 2  levelNP_CS_reward_laserepochON1st_noshock   4.0
# 3  levelNP_CS_reward_laserepochON1st_noshock   4.0
# 4  levelNP_CS_reward_laserepochON1st_noshock   1.0

# %% [markdown]
# - The Dataframe the contains the recording data for all the files.
#     - The 1st row is the first data entries for each type of data(with the type being specified by the column label). This does not mean that all these are related or occured for the same trial. i.e. There can be many port entries and exits for a subject before and after a tone is played.
#     - Each recording session will usually have a few thousand rows(although, most of of the columns will probably be blank by the end). And then after the last row of one session, the next row will be the next session with a different `file_path`

# %%
concatted_medpc_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0         12.34           64.0      399.0           0.0              60.01
# 1         14.60          144.0      399.0           0.0             140.01
# 2         23.95          234.0      399.0           0.0             230.01
# 3         31.83          314.0      399.0           0.0             310.01
# 4         31.99          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (B)shockintensity      date  subject  \
# 0        12.39        1.0                0.0  20220506  3.4 (2)
# 1        14.79        1.0                0.0  20220506  3.4 (2)
# 2        24.88        1.0                0.0  20220506  3.4 (2)
# 3        31.90        1.0                0.0  20220506  3.4 (2)
# 4        32.09        1.0                0.0  20220506  3.4 (2)
#
#                                            file_path
# 0  ./data/timestamp_dataframes/2022-05-06_12h59m_...
# 1  ./data/timestamp_dataframes/2022-05-06_12h59m_...
# 2  ./data/timestamp_dataframes/2022-05-06_12h59m_...
# 3  ./data/timestamp_dataframes/2022-05-06_12h59m_...
# 4  ./data/timestamp_dataframes/2022-05-06_12h59m_...

# %% [markdown]
# - This dataframe combines the recording data and metadata dataframes. This is done by using the subject ID as a common column to merge together off of.

# %%
recording_and_metadata_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0         12.34           64.0      399.0           0.0              60.01
# 1         14.60          144.0      399.0           0.0             140.01
# 2         23.95          234.0      399.0           0.0             230.01
# 3         31.83          314.0      399.0           0.0             310.01
# 4         31.99          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (B)shockintensity      date  subject  ...  \
# 0        12.39        1.0                0.0  20220506  3.4 (2)  ...
# 1        14.79        1.0                0.0  20220506  3.4 (2)  ...
# 2        24.88        1.0                0.0  20220506  3.4 (2)  ...
# 3        31.90        1.0                0.0  20220506  3.4 (2)  ...
# 4        32.09        1.0                0.0  20220506  3.4 (2)  ...
#
#   Start Date  End Date  Subject      Experiment   Group Box Start Time  \
# 0   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 1   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 2   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 3   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 4   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
#
#    End Time                                        MSN cage
# 0  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 1  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 2  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 3  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 4  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Getting the Cage Numbers and the Dates for the file names

# %% [markdown]
# - Seeing if any rows have NaN values for the cages

# %%
metadata_df[pd.isna(metadata_df["cage"])]
# Out:
#                                                 index  \
# 88  ./data/timestamp_dataframes/2022-05-16_10h57m_...
#
#                                              File Start Date  End Date  \
# 88  C:\MED-PC\Data\2022-05-16_10h57m_Subject .txt   05/16/22  05/16/22
#
#    Subject Experiment Group  Box Start Time  End Time       MSN  cage
# 88     NaN        NaN   NaN    1   10:57:55  11:01:10  pumptest   NaN

# %% [markdown]
# - Dropping the NaN values so we can get the cage numbers

# %%
metadata_df = metadata_df.dropna(subset=["cage"])

# %%
# removing blank spaces
cage_numbers = [str(int(number)) for number in metadata_df["cage"].unique() if number is not np.nan]
# sorting numbers
cage_numbers = sorted(cage_numbers)
cage_numbers_for_title = "_".join(cage_numbers)

# %%
cage_numbers_for_title
# Out:
# '1_2_3_4'

# %%
# Getting the first and last recording date to get a range
earliest_date = concatted_medpc_df["date"].min()
latest_date = concatted_medpc_df["date"].max()

# %%
earliest_date
# Out:
# 20220503

# %%
latest_date
# Out:
# 20220516

# %% [markdown]
# # Getting the First Port Entry After Each Tone

# %% [markdown]
# - Getting all the rows that correspond to one of the files paths. This will be the equivalent of getting all the rows for one session

# %%
example_one_session_recording_df = recording_and_metadata_df[recording_and_metadata_df["file_path"] == recording_and_metadata_df["file_path"].unique()[0]
]

# %% [markdown]
# - Everything looks normal enough

# %%
example_one_session_recording_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0         12.34           64.0      399.0           0.0              60.01
# 1         14.60          144.0      399.0           0.0             140.01
# 2         23.95          234.0      399.0           0.0             230.01
# 3         31.83          314.0      399.0           0.0             310.01
# 4         31.99          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (B)shockintensity      date  subject  ...  \
# 0        12.39        1.0                0.0  20220506  3.4 (2)  ...
# 1        14.79        1.0                0.0  20220506  3.4 (2)  ...
# 2        24.88        1.0                0.0  20220506  3.4 (2)  ...
# 3        31.90        1.0                0.0  20220506  3.4 (2)  ...
# 4        32.09        1.0                0.0  20220506  3.4 (2)  ...
#
#   Start Date  End Date  Subject      Experiment   Group Box Start Time  \
# 0   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 1   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 2   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 3   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 4   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
#
#    End Time                                        MSN cage
# 0  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 1  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 2  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 3  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 4  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
#
# [5 rows x 23 columns]

# %% [markdown]
# - `(S)CSpresentation` is the time that the tone starts playing. MED-PC starts inputting in random numbers that are in the 1000's. So we will remove these

# %%
example_one_session_recording_df[50:60]
# Out:
#     (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 50        438.69            NaN        NaN           0.0             9000.0
# 51        446.71            NaN        NaN           0.0            12000.0
# 52        452.60            NaN        NaN           0.0             9000.0
# 53        460.11            NaN        NaN           0.0             8500.0
# 54        464.04            NaN        NaN           0.0             9000.0
# 55        475.64            NaN        NaN           0.0             9500.0
# 56        484.23            NaN        NaN           0.0            12000.0
# 57        487.74            NaN        NaN           0.0             8000.0
# 58        495.85            NaN        NaN           0.0             9500.0
# 59        505.47            NaN        NaN           0.0             8000.0
#
#     (N)Portexit  (K)CStype  (B)shockintensity      date  subject  ...  \
# 50       439.62        0.0                0.0  20220506  3.4 (2)  ...
# 51       447.92        0.0                0.0  20220506  3.4 (2)  ...
# 52       453.28        0.0                0.0  20220506  3.4 (2)  ...
# 53       461.21        0.0                0.0  20220506  3.4 (2)  ...
# 54       464.49        0.0                0.0  20220506  3.4 (2)  ...
# 55       476.41        0.0                0.0  20220506  3.4 (2)  ...
# 56       484.53        0.0                0.0  20220506  3.4 (2)  ...
# 57       489.12        0.0                0.0  20220506  3.4 (2)  ...
# 58       499.31        0.0                0.0  20220506  3.4 (2)  ...
# 59       507.17        0.0                0.0  20220506  3.4 (2)  ...
#
#    Start Date  End Date  Subject      Experiment   Group Box Start Time  \
# 50   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 51   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 52   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 53   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 54   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 55   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 56   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 57   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 58   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 59   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
#
#     End Time                                        MSN cage
# 50  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 51  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 52  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 53  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 54  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 55  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 56  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 57  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 58  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 59  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
#
# [10 rows x 23 columns]

# %% [markdown]
# - `(S)CSpresentation` then starts adding blanks(NaN) so we will remove these too

# %%
example_one_session_recording_df.tail()
# Out:
#       (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 2536           NaN            NaN        NaN           NaN                NaN
# 2537           NaN            NaN        NaN           NaN                NaN
# 2538           NaN            NaN        NaN           NaN                NaN
# 2539           NaN            NaN        NaN           NaN                NaN
# 2540           NaN            NaN        NaN           NaN                NaN
#
#       (N)Portexit  (K)CStype  (B)shockintensity      date  subject  ...  \
# 2536          NaN        1.0                NaN  20220506  3.4 (2)  ...
# 2537          NaN        1.0                NaN  20220506  3.4 (2)  ...
# 2538          NaN        1.0                NaN  20220506  3.4 (2)  ...
# 2539          NaN        1.0                NaN  20220506  3.4 (2)  ...
# 2540          NaN        1.0                NaN  20220506  3.4 (2)  ...
#
#      Start Date  End Date  Subject      Experiment   Group Box Start Time  \
# 2536   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 2537   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 2538   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 2539   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 2540   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
#
#       End Time                                        MSN cage
# 2536  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 2537  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 2538  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 2539  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 2540  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
#
# [5 rows x 23 columns]

# %% [markdown]
# - Getting the tones that were actually used for the recordings

# %%
example_one_session_valid_tones = processing.tone.get_valid_tones(example_one_session_recording_df["(S)CSpresentation"])

# %%
example_one_session_valid_tones
# Out:
# 0       60.01
# 1      140.01
# 2      230.01
# 3      310.01
# 4      385.01
# 5      485.01
# 6      580.01
# 7      670.01
# 8      750.01
# 9      840.01
# 10     940.01
# 11    1030.01
# 12    1150.01
# 13    1240.01
# 14    1325.01
# 15    1415.01
# 16    1510.01
# 17    1630.01
# 18    1710.01
# 19    1805.01
# 20    1885.01
# 21    1975.01
# 22    2055.01
# 23    2130.01
# 24    2230.01
# 25    2325.01
# 26    2415.01
# 27    2495.01
# 28    2585.01
# 29    2685.01
# 30    2775.01
# 31    2895.01
# 32    2985.01
# 33    3070.01
# 34    3160.01
# 35    3255.01
# 36    3345.01
# 37    3425.01
# 38    3515.01
# 39    3615.01
# Name: (S)CSpresentation, dtype: float64

# %% [markdown]
# - With these tone playing times, we will get the first port entry that comes after the tone playing time
#     - This was done by getting all the port entries that came after the tone. And then getting the port entry time that was earliest in time(aka smallest number)

# %%
processing.tone.get_first_port_entries_after_tone(tone_pd_series=example_one_session_valid_tones, port_entries_pd_series=example_one_session_recording_df["(P)Portentry"], port_exits_pd_series=example_one_session_recording_df["(N)Portexit"])
# Out:
#     current_tone_time  first_port_entry_after_tone  \
# 0               60.01                        69.00
# 1              140.01                       148.27
# 2              230.01                       231.91
# 3              310.01                       320.97
# 4              385.01                       394.75
# 5              485.01                       487.74
# 6              580.01                       584.00
# 7              670.01                       676.26
# 8              750.01                       777.83
# 9              840.01                       840.06
# 10             940.01                       943.30
# 11            1030.01                      1035.05
# 12            1150.01                      1224.44
# 13            1240.01                      1253.35
# 14            1325.01                      1325.78
# 15            1415.01                      1419.19
# 16            1510.01                      1516.06
# 17            1630.01                      1632.25
# 18            1710.01                      1713.50
# 19            1805.01                      1806.80
# 20            1885.01                      1889.58
# 21            1975.01                      1975.87
# 22            2055.01                      2055.51
# 23            2130.01                      2192.23
# 24            2230.01                      2230.20
# 25            2325.01                      2332.53
# 26            2415.01                      2420.74
# 27            2495.01                      2495.05
# 28            2585.01                      2586.63
# 29            2685.01                      2685.35
# 30            2775.01                      2777.86
# 31            2895.01                      2898.99
# 32            2985.01                      2986.95
# 33            3070.01                      3071.11
# 34            3160.01                      3161.54
# 35            3255.01                      3256.06
# 36            3345.01                      3348.54
# 37            3425.01                      3430.63
# 38            3515.01                      3515.62
# 39            3615.01                      3615.67
#
#     port_exit_after_first_port_entry_after_tone
# 0                                         73.66
# 1                                        151.69
# 2                                        233.40
# 3                                        327.71
# 4                                        398.05
# 5                                        489.12
# 6                                        598.64
# 7                                        676.30
# 8                                        782.02
# 9                                        841.92
# 10                                       944.29
# 11                                      1045.48
# 12                                      1229.68
# 13                                      1255.06
# 14                                      1326.30
# 15                                      1443.29
# 16                                      1530.28
# 17                                      1633.57
# 18                                      1714.08
# 19                                      1807.30
# 20                                      1890.21
# 21                                      1976.10
# 22                                      2056.25
# 23                                      2195.37
# 24                                      2231.21
# 25                                      2334.20
# 26                                      2422.72
# 27                                      2495.64
# 28                                      2587.45
# 29                                      2685.98
# 30                                      2778.77
# 31                                      2903.65
# 32                                      2987.99
# 33                                      3072.07
# 34                                      3161.57
# 35                                      3256.61
# 36                                      3349.14
# 37                                      3433.94
# 38                                      3516.01
# 39                                      3616.30

# %% [markdown]
# - Getting the first port entry times for all the sessions

# %%
concatted_first_porty_entry_dataframe = processing.tone.get_concatted_first_porty_entry_after_tone_dataframe(concatted_medpc_df=concatted_medpc_df)

# %%
concatted_first_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        69.00
# 1             140.01                       148.27
# 2             230.01                       231.91
# 3             310.01                       320.97
# 4             385.01                       394.75
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        73.66
# 1                                       151.69
# 2                                       233.40
# 3                                       327.71
# 4                                       398.05
#
#                                            file_path      date  subject
# 0  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 1  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 2  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 3  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 4  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)

# %%
concatted_first_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        69.00
# 1             140.01                       148.27
# 2             230.01                       231.91
# 3             310.01                       320.97
# 4             385.01                       394.75
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        73.66
# 1                                       151.69
# 2                                       233.40
# 3                                       327.71
# 4                                       398.05
#
#                                            file_path      date  subject
# 0  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 1  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 2  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 3  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 4  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)

# %% [markdown]
# # Getting the Last Port Entry Before the Tone

# %% [markdown]
# - We will do the same, but get the port entries that happened before the tone

# %%
port_entries_pd_series = example_one_session_recording_df["(P)Portentry"]
port_exit_pd_series = example_one_session_recording_df["(N)Portexit"]

# %% [markdown]
# - Example run for one session

# %%
example_last_port_entries_before_tone = processing.tone.get_last_port_entries_before_tone(tone_pd_series=example_one_session_valid_tones, port_entries_pd_series=port_entries_pd_series, port_exits_pd_series=port_exit_pd_series)

# %%
example_last_port_entries_before_tone
# Out:
#     current_tone_time  last_port_entry_before_tone  \
# 0               60.01                        54.90
# 1              140.01                       125.14
# 2              230.01                       224.43
# 3              310.01                       298.91
# 4              385.01                       384.15
# 5              485.01                       484.23
# 6              580.01                       578.18
# 7              670.01                       667.64
# 8              750.01                       734.83
# 9              840.01                       826.15
# 10             940.01                       938.94
# 11            1030.01                      1019.19
# 12            1150.01                      1129.43
# 13            1240.01                      1237.63
# 14            1325.01                      1322.93
# 15            1415.01                      1413.21
# 16            1510.01                      1482.64
# 17            1630.01                      1628.06
# 18            1710.01                      1707.54
# 19            1805.01                      1799.74
# 20            1885.01                      1878.58
# 21            1975.01                      1973.96
# 22            2055.01                      2050.73
# 23            2130.01                      2093.55
# 24            2230.01                      2203.14
# 25            2325.01                      2256.55
# 26            2415.01                      2408.09
# 27            2495.01                      2481.02
# 28            2585.01                      2579.63
# 29            2685.01                      2670.39
# 30            2775.01                      2770.42
# 31            2895.01                      2893.25
# 32            2985.01                      2979.03
# 33            3070.01                      3063.86
# 34            3160.01                      3158.72
# 35            3255.01                      3243.97
# 36            3345.01                      3338.56
# 37            3425.01                      3421.11
# 38            3515.01                      3508.76
# 39            3615.01                      3603.03
#
#     port_exit_after_last_port_entry_before_tone
# 0                                         55.73
# 1                                        126.71
# 2                                        225.00
# 3                                        299.28
# 4                                        384.46
# 5                                        484.53
# 6                                        579.04
# 7                                        668.20
# 8                                        734.87
# 9                                        826.57
# 10                                       939.65
# 11                                      1020.65
# 12                                      1131.25
# 13                                      1238.27
# 14                                      1323.39
# 15                                      1414.46
# 16                                      1483.10
# 17                                      1628.48
# 18                                      1707.95
# 19                                      1800.34
# 20                                      1880.22
# 21                                      1975.69
# 22                                      2051.14
# 23                                      2094.05
# 24                                      2203.72
# 25                                      2257.74
# 26                                      2409.25
# 27                                      2481.40
# 28                                      2580.30
# 29                                      2671.16
# 30                                      2771.00
# 31                                      2893.55
# 32                                      2979.41
# 33                                      3064.24
# 34                                      3159.19
# 35                                      3244.86
# 36                                      3338.85
# 37                                      3422.70
# 38                                      3509.13
# 39                                      3607.14

# %% [markdown]
# - Getting all the port entries that happen before the tone for all sessions

# %%
concatted_last_porty_entry_dataframe = processing.tone.get_concatted_last_porty_entry_before_tone_dataframe(concatted_medpc_df=concatted_medpc_df)

# %%
concatted_last_porty_entry_dataframe
# Out:
#       current_tone_time  last_port_entry_before_tone  \
# 0                 60.01                        54.90
# 1                140.01                       125.14
# 2                230.01                       224.43
# 3                310.01                       298.91
# 4                385.01                       384.15
# ...                 ...                          ...
# 6548            3160.01                      3152.67
# 6549            3255.01                      3245.72
# 6550            3345.01                      3344.18
# 6551            3425.01                      3423.33
# 6552            3515.01                      3509.84
#
#       port_exit_after_last_port_entry_before_tone  \
# 0                                           55.73
# 1                                          126.71
# 2                                          225.00
# 3                                          299.28
# 4                                          384.46
# ...                                           ...
# 6548                                      3155.50
# 6549                                      3246.89
# 6550                                      3345.95
# 6551                                      3424.15
# 6552                                      3509.97
#
#                                               file_path      date  subject
# 0     ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 1     ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 2     ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 3     ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 4     ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# ...                                                 ...       ...      ...
# 6548  ./data/timestamp_dataframes/2022-05-08_11h14m_...  20220508      1.3
# 6549  ./data/timestamp_dataframes/2022-05-08_11h14m_...  20220508      1.3
# 6550  ./data/timestamp_dataframes/2022-05-08_11h14m_...  20220508      1.3
# 6551  ./data/timestamp_dataframes/2022-05-08_11h14m_...  20220508      1.3
# 6552  ./data/timestamp_dataframes/2022-05-08_11h14m_...  20220508      1.3
#
# [6553 rows x 6 columns]

# %% [markdown]
# ## Merging the dataframes for the first port entry after the tone and the last tone before the tone

# %%
# Combining it based on the tone times and the file path
concatted_first_and_last_porty_entry_dataframe = pd.merge(concatted_first_porty_entry_dataframe, concatted_last_porty_entry_dataframe,  how='left', left_on=['current_tone_time','file_path'], right_on = ['current_tone_time','file_path'], suffixes=('', '_y'))
# Dropping all columns that are duplicates
concatted_first_and_last_porty_entry_dataframe = concatted_first_and_last_porty_entry_dataframe.drop(concatted_first_and_last_porty_entry_dataframe.filter(regex='_y$').columns.tolist(), axis=1)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        69.00
# 1             140.01                       148.27
# 2             230.01                       231.91
# 3             310.01                       320.97
# 4             385.01                       394.75
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        73.66
# 1                                       151.69
# 2                                       233.40
# 3                                       327.71
# 4                                       398.05
#
#                                            file_path      date  subject  \
# 0  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 1  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 2  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 3  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 4  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone
# 0                        54.90                                        55.73
# 1                       125.14                                       126.71
# 2                       224.43                                       225.00
# 3                       298.91                                       299.28
# 4                       384.15                                       384.46

# %%
concatted_first_and_last_porty_entry_dataframe.shape
# Out:
# (6553, 8)

# %% [markdown]
# - Getting all the rows that have port entry to port exit time that overlaps with the tone playing
#     - This would be the port entries that came before the tone, but had a port exit after

# %%
port_entries_that_overlap = concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["port_exit_after_last_port_entry_before_tone"] >= concatted_first_and_last_porty_entry_dataframe["current_tone_time"]]

# %%
port_entries_that_overlap.head()
# Out:
#     current_tone_time  first_port_entry_after_tone  \
# 21            1975.01                      1975.87
# 47             670.01                       670.27
# 53            1240.01                      1242.58
# 62            2055.01                      2067.11
# 63            2130.01                      2134.46
#
#     port_exit_after_first_port_entry_after_tone  \
# 21                                      1976.10
# 47                                       670.89
# 53                                      1243.36
# 62                                      2073.44
# 63                                      2134.66
#
#                                             file_path      date  subject  \
# 21  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 47  ./data/timestamp_dataframes/2022-05-06_08h37m_...  20220506      2.3
# 53  ./data/timestamp_dataframes/2022-05-06_08h37m_...  20220506      2.3
# 62  ./data/timestamp_dataframes/2022-05-06_08h37m_...  20220506      2.3
# 63  ./data/timestamp_dataframes/2022-05-06_08h37m_...  20220506      2.3
#
#     last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone
# 21                      1973.96                                      1975.69
# 47                       669.88                                       670.17
# 53                      1239.45                                      1240.12
# 62                      2052.44                                      2055.04
# 63                      2129.20                                      2130.11

# %%
port_entries_that_overlap.shape
# Out:
# (1507, 8)

# %% [markdown]
# # Getting the Latency for Each Session of a Tone Playing

# %% [markdown]
# - To calculate latency, we would just subtract the time of the first port entry to that of the tone playing

# %%
concatted_first_and_last_porty_entry_dataframe["latency"] = concatted_first_porty_entry_dataframe["first_port_entry_after_tone"] - concatted_first_and_last_porty_entry_dataframe["current_tone_time"]

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        69.00
# 1             140.01                       148.27
# 2             230.01                       231.91
# 3             310.01                       320.97
# 4             385.01                       394.75
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        73.66
# 1                                       151.69
# 2                                       233.40
# 3                                       327.71
# 4                                       398.05
#
#                                            file_path      date  subject  \
# 0  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 1  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 2  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 3  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 4  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                        54.90                                        55.73
# 1                       125.14                                       126.71
# 2                       224.43                                       225.00
# 3                       298.91                                       299.28
# 4                       384.15                                       384.46
#
#    latency
# 0     8.99
# 1     8.26
# 2     1.90
# 3    10.96
# 4     9.74

# %% [markdown]
# - For all the latencies that are are greater than 30 seconds, we changed the latency to 30 seconds

# %%
concatted_first_and_last_porty_entry_dataframe["latency_adjusted_greater_than_30"] = concatted_first_and_last_porty_entry_dataframe["latency"].apply(lambda x: 30 if x >= 30 else x)

# %%
concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["latency"] >= 30].head()
# Out:
#      current_tone_time  first_port_entry_after_tone  \
# 12             1150.01                      1224.44
# 23             2130.01                      2192.23
# 109            2585.01                      2615.82
# 132             940.01                       982.59
# 154            2985.01                      3023.64
#
#      port_exit_after_first_port_entry_after_tone  \
# 12                                       1229.68
# 23                                       2195.37
# 109                                      2619.22
# 132                                       982.62
# 154                                      3027.26
#
#                                              file_path      date  subject  \
# 12   ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 23   ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 109  ./data/timestamp_dataframes/2022-05-10_14h40m_...  20220510  4.3 (3)
# 132  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  4.3 (3)
# 154  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  4.3 (3)
#
#      last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 12                       1129.43                                      1131.25
# 23                       2093.55                                      2094.05
# 109                      2580.63                                      2581.81
# 132                       931.00                                       931.97
# 154                      2982.57                                      2984.74
#
#      latency  latency_adjusted_greater_than_30
# 12     74.43                              30.0
# 23     62.22                              30.0
# 109    30.81                              30.0
# 132    42.58                              30.0
# 154    38.63                              30.0

# %% [markdown]
# # Seeing which port entries and port exit durations overlap with the tone

# %% [markdown]
# - Making a column that states whether or not the last port entry before the tone has a port exit after the tone. This would mean that they are overlapping.

# %%
concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"] = concatted_first_and_last_porty_entry_dataframe.apply(lambda row: True if row["port_exit_after_last_port_entry_before_tone"] >= row["current_tone_time"] else False, axis=1)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        69.00
# 1             140.01                       148.27
# 2             230.01                       231.91
# 3             310.01                       320.97
# 4             385.01                       394.75
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        73.66
# 1                                       151.69
# 2                                       233.40
# 3                                       327.71
# 4                                       398.05
#
#                                            file_path      date  subject  \
# 0  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 1  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 2  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 3  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 4  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                        54.90                                        55.73
# 1                       125.14                                       126.71
# 2                       224.43                                       225.00
# 3                       298.91                                       299.28
# 4                       384.15                                       384.46
#
#    latency  latency_adjusted_greater_than_30  overlapping_port_entry_with_tone
# 0     8.99                              8.99                             False
# 1     8.26                              8.26                             False
# 2     1.90                              1.90                             False
# 3    10.96                             10.96                             False
# 4     9.74                              9.74                             False

# %% [markdown]
# - Comparing the latencies of the first port entry after the tone between these two groups:
#     - 1. Those with the last port entry before the tone that has a port exit after the tone("overlapping" group)
#     - 2. Those with the last port entry before the tone that has a port exit before the tone("nonoverlapping" group)

# %%
overlapping_df = concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"]]

# %%
non_overlapping_df = concatted_first_and_last_porty_entry_dataframe[~concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"]]

# %% [markdown]
# - Number of rows of overlapping and nonoverlapping last port entries before the tone

# %%
overlapping_df.shape
# Out:
# (1507, 11)

# %%
non_overlapping_df.shape
# Out:
# (5046, 11)

# %% [markdown]
# - Latency between the tone playing and the first port entry after the tone

# %%
overlapping_df["latency"].mean()
# Out:
# 13.61821926910289

# %%
non_overlapping_df["latency"].mean()
# Out:
# 14.063250805152887

# %% [markdown]
# - Latency between the tone playing and the first port entry after the tone. This had been adjusted so that all latencies that are greater than 30 seconds were adjusted to be just 30 seconds.

# %%
overlapping_df["latency_adjusted_greater_than_30"].mean()
# Out:
# 12.339707641195924

# %%
non_overlapping_df["latency_adjusted_greater_than_30"].mean()
# Out:
# 8.51532407407399

# %% [markdown]
# # Adjusting the Latencies if the Port Entries/Exit Overlap With the Tone Times

# %% [markdown]
# - For all the rows with overlapping last port entries before the tone, we will adjust the latency of the tone to the first port entry after the tone to 0. (Because the first port entry after the tone would be considered to be the same as the last port entry before the tone)

# %%
concatted_first_and_last_porty_entry_dataframe["latency_adjusted_overlap"] = concatted_first_and_last_porty_entry_dataframe.apply(lambda row: 0 if row["overlapping_port_entry_with_tone"] else row["latency_adjusted_greater_than_30"], axis=1)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        69.00
# 1             140.01                       148.27
# 2             230.01                       231.91
# 3             310.01                       320.97
# 4             385.01                       394.75
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        73.66
# 1                                       151.69
# 2                                       233.40
# 3                                       327.71
# 4                                       398.05
#
#                                            file_path      date  subject  \
# 0  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 1  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 2  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 3  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 4  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                        54.90                                        55.73
# 1                       125.14                                       126.71
# 2                       224.43                                       225.00
# 3                       298.91                                       299.28
# 4                       384.15                                       384.46
#
#    latency  latency_adjusted_greater_than_30  \
# 0     8.99                              8.99
# 1     8.26                              8.26
# 2     1.90                              1.90
# 3    10.96                             10.96
# 4     9.74                              9.74
#
#    overlapping_port_entry_with_tone  latency_adjusted_overlap
# 0                             False                      8.99
# 1                             False                      8.26
# 2                             False                      1.90
# 3                             False                     10.96
# 4                             False                      9.74

# %% [markdown]
# - All the rows with overlapping last port entries before the tone

# %%
concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"]].head()
# Out:
#     current_tone_time  first_port_entry_after_tone  \
# 21            1975.01                      1975.87
# 47             670.01                       670.27
# 53            1240.01                      1242.58
# 62            2055.01                      2067.11
# 63            2130.01                      2134.46
#
#     port_exit_after_first_port_entry_after_tone  \
# 21                                      1976.10
# 47                                       670.89
# 53                                      1243.36
# 62                                      2073.44
# 63                                      2134.66
#
#                                             file_path      date  subject  \
# 21  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 47  ./data/timestamp_dataframes/2022-05-06_08h37m_...  20220506      2.3
# 53  ./data/timestamp_dataframes/2022-05-06_08h37m_...  20220506      2.3
# 62  ./data/timestamp_dataframes/2022-05-06_08h37m_...  20220506      2.3
# 63  ./data/timestamp_dataframes/2022-05-06_08h37m_...  20220506      2.3
#
#     last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 21                      1973.96                                      1975.69
# 47                       669.88                                       670.17
# 53                      1239.45                                      1240.12
# 62                      2052.44                                      2055.04
# 63                      2129.20                                      2130.11
#
#     latency  latency_adjusted_greater_than_30  \
# 21     0.86                              0.86
# 47     0.26                              0.26
# 53     2.57                              2.57
# 62    12.10                             12.10
# 63     4.45                              4.45
#
#     overlapping_port_entry_with_tone  latency_adjusted_overlap
# 21                              True                       0.0
# 47                              True                       0.0
# 53                              True                       0.0
# 62                              True                       0.0
# 63                              True                       0.0

# %% [markdown]
# ## Labeling if a row's latency is less than 10 seconds or not

# %% [markdown]
# - We will be getting the ratio of latencies(from the time that the tone played, to the first port entry after the tone) that are less than 10 seconds for each session. So we will label all the adjusted latencies that are less than 10 seconds as `True`, and the those with latencies that are greater than 10 seconds as `False`

# %%
concatted_first_and_last_porty_entry_dataframe["latency_less_than_10_seconds"] = concatted_first_and_last_porty_entry_dataframe["latency_adjusted_greater_than_30"].apply(lambda x: True if x <= 10 else False)

# %%
concatted_first_and_last_porty_entry_dataframe["overlap_adjusted_latency_less_than_10_seconds"] = concatted_first_and_last_porty_entry_dataframe["latency_adjusted_overlap"].apply(lambda x: True if x <= 10 else False)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        69.00
# 1             140.01                       148.27
# 2             230.01                       231.91
# 3             310.01                       320.97
# 4             385.01                       394.75
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        73.66
# 1                                       151.69
# 2                                       233.40
# 3                                       327.71
# 4                                       398.05
#
#                                            file_path      date  subject  \
# 0  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 1  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 2  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 3  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
# 4  ./data/timestamp_dataframes/2022-05-06_12h59m_...  20220506  3.4 (2)
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                        54.90                                        55.73
# 1                       125.14                                       126.71
# 2                       224.43                                       225.00
# 3                       298.91                                       299.28
# 4                       384.15                                       384.46
#
#    latency  latency_adjusted_greater_than_30  \
# 0     8.99                              8.99
# 1     8.26                              8.26
# 2     1.90                              1.90
# 3    10.96                             10.96
# 4     9.74                              9.74
#
#    overlapping_port_entry_with_tone  latency_adjusted_overlap  \
# 0                             False                      8.99
# 1                             False                      8.26
# 2                             False                      1.90
# 3                             False                     10.96
# 4                             False                      9.74
#
#    latency_less_than_10_seconds  overlap_adjusted_latency_less_than_10_seconds
# 0                          True                                           True
# 1                          True                                           True
# 2                          True                                           True
# 3                         False                                          False
# 4                          True                                           True

# %% [markdown]
# # Making Dataframes that have Each Subject as the Row and Each Date as the Column

# %% [markdown]
# - Pivot plots allow us to make columns out of each unique entry in a selected column. (For this, it will be the date column that we will turn into columns) The index for the rows will be each unique entry in another column. (For this, it will be the subject's ID) And the values will be the aggregate of the values that have both the values in the previous two selected columns. (For this it will be the latency columns and we will take the mean)
#     - https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html

# %% [markdown]
# - Making a folder for all the pivotplots

# %% [markdown]
# # NOTE: If you decide to change the cage numbers or the dates used from the original ones from the imported dataframes, you will need to change the subsequent path to the cage number and dates you are using

# %%
pivot_plot_output_directory = "./data/subject_rows_with_date_columns_dataframes/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
pivot_plot_output_directory
# Out:
# './data/subject_rows_with_date_columns_dataframes/cage_1_2_3_4_date_20220503_20220516'

# %%
os.makedirs(pivot_plot_output_directory, exist_ok=True)

# %% [markdown]
# - Making a pivot plot with the regular latency

# %%
all_latency_pivot_plot = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='latency', \
                                        index=['subject'], columns=['date'], aggfunc=np.mean)

# %%
all_latency_pivot_plot.head()
# Out:
# date      20220503   20220504    20220505   20220506  20220507   20220508  \
# subject
# 1.1      42.218000   6.046829   11.537750   5.956341   3.59800  10.863590
# 1.2      49.817857  25.471538   13.112195   7.628250   5.64800   4.987692
# 1.3      86.598000  36.300526  373.844750  14.234500   7.00100   8.922821
# 1.4      61.345333  10.832683  125.872000  29.977805  12.33400   6.594103
# 2.1      30.953125   7.548500   18.269268   5.618500   3.92925   6.335897
#
# date     20220509  20220510  20220511  20220512   20220516
# subject
# 1.1       7.18400  6.876750   9.92700       NaN   8.523659
# 1.2       4.09525  9.064000   6.92650  18.89000  10.487000
# 1.3       8.97225  8.345250   7.85100  16.60550  13.887250
# 1.4       5.93475  8.869625  19.38650       NaN  12.103659
# 2.1       5.16775  6.824000   4.94175  17.10825   9.888500

# %% [markdown]
# - Getting the cage numbers for each subject and then making a dictionary out of it
#     - This will be used to add the cage information to the pivot plots

# %%
# Converting the cage numbers from floats to integers
# When the metadata is imported from the csv files, the cage number is imported as a float
metadata_df["cage"] = metadata_df["cage"].astype(int)

# %%
subject_to_cage = pd.Series(metadata_df["cage"].values,index=metadata_df["Subject"].values).to_dict()

# %%
subject_to_cage
# Out:
# {'3.4 (2)': 4,
#  '2.3': 1,
#  '4.3 (3)': 4,
#  '2.1': 2,
#  '1.2': 2,
#  '1.1': 1,
#  '1.3': 2,
#  '2.4': 2,
#  '4.1 (1)': 3,
#  '4.4 (4)': 4,
#  '3.3 (4)': 3,
#  '3.2 (2)': 3,
#  '1.4': 1,
#  '3.1 (1)': 4,
#  '2.2': 1,
#  '4.2 (3)': 3}

# %% [markdown]
# - Adding the cage information with the dictionary

# %%
all_latency_pivot_plot["cage"] = all_latency_pivot_plot.index.map(subject_to_cage)

# %%
all_latency_pivot_plot.head()
# Out:
# date      20220503   20220504    20220505   20220506  20220507   20220508  \
# subject
# 1.1      42.218000   6.046829   11.537750   5.956341   3.59800  10.863590
# 1.2      49.817857  25.471538   13.112195   7.628250   5.64800   4.987692
# 1.3      86.598000  36.300526  373.844750  14.234500   7.00100   8.922821
# 1.4      61.345333  10.832683  125.872000  29.977805  12.33400   6.594103
# 2.1      30.953125   7.548500   18.269268   5.618500   3.92925   6.335897
#
# date     20220509  20220510  20220511  20220512   20220516  cage
# subject
# 1.1       7.18400  6.876750   9.92700       NaN   8.523659     1
# 1.2       4.09525  9.064000   6.92650  18.89000  10.487000     2
# 1.3       8.97225  8.345250   7.85100  16.60550  13.887250     2
# 1.4       5.93475  8.869625  19.38650       NaN  12.103659     1
# 2.1       5.16775  6.824000   4.94175  17.10825   9.888500     2

# %%
os.path.join(pivot_plot_output_directory, "original_latency_pivot_plot_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date))
# Out:
# './data/subject_rows_with_date_columns_dataframes/cage_1_2_3_4_date_20220503_20220516/original_latency_pivot_plot_cage_1_2_3_4_date_20220503_20220516.csv'

# %%
all_latency_pivot_plot.to_csv(os.path.join(pivot_plot_output_directory, "original_latency_pivot_plot_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
all_latency_pivot_plot.to_excel(os.path.join(pivot_plot_output_directory, "original_latency_pivot_plot_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %% [markdown]
# - Doing the same thing for the adjust latency

# %%
adjusted_latency_pivot_plot = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='latency_adjusted_greater_than_30', index=['subject'],

                    columns=['date'], aggfunc=np.mean)

# %%
adjusted_latency_pivot_plot["cage"] = adjusted_latency_pivot_plot.index.map(subject_to_cage)

# %%
adjusted_latency_pivot_plot.head()
# Out:
# date      20220503   20220504   20220505   20220506  20220507   20220508  \
# subject
# 1.1      19.980000   6.046829   9.446750   5.956341   3.59800  10.670769
# 1.2      27.120000  17.573077  11.960732   7.628250   5.64800   4.987692
# 1.3      27.746000  21.131316  26.896000  10.405250   6.65950   8.282564
# 1.4      22.285333  10.832683  24.336000  12.144634   9.19425   6.594103
# 2.1      17.701875   7.473000  10.245122   5.289500   3.92925   5.700256
#
# date     20220509  20220510  20220511  20220512   20220516  cage
# subject
# 1.1       7.18400  6.862375   9.92350       NaN   8.523659     1
# 1.2       4.09525  7.562000   6.92650  16.95725   9.764250     2
# 1.3       7.27000  8.273500   7.78250  15.18050  13.352000     2
# 1.4       5.93475  8.779250  14.12675       NaN  11.990732     1
# 2.1       5.16775  6.824000   4.94175  15.18450   9.871500     2

# %%
adjusted_latency_pivot_plot.to_csv(os.path.join(pivot_plot_output_directory, "adjusted_latency_pivot_plot_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
adjusted_latency_pivot_plot.to_excel(os.path.join(pivot_plot_output_directory, "adjusted_latency_pivot_plot_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %% [markdown]
# - Doing the same for the ratio of latencies that are less than 10 seconds

# %%
less_than_10_latency_df = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='latency_less_than_10_seconds', index=['subject'],

                    columns=['date'], aggfunc=np.mean)

# %%
less_than_10_latency_df["cage"] = less_than_10_latency_df.index.map(subject_to_cage)

# %%
less_than_10_latency_df
# Out:
# date     20220503  20220504  20220505  20220506  20220507  20220508  20220509  \
# subject
# 1.1      0.333333  0.780488  0.675000  0.829268     0.975  0.589744     0.725
# 1.2      0.062500  0.400000  0.487805  0.675000     0.925  0.923077     0.950
# 1.3      0.000000  0.225000  0.073171  0.600000     0.825  0.717949     0.700
# 1.4      0.200000  0.487805  0.025000  0.512195     0.600  0.769231     0.825
# 2.1      0.235294  0.775000  0.658537  0.875000     0.925  0.820513     0.775
# 2.2      0.200000  0.487805  0.750000  0.804878     0.925  0.820513     0.675
# 2.3      0.066667  0.487805  0.725000  0.902439     0.900  0.923077     0.925
# 2.4      0.250000  0.275000  0.536585  0.675000     0.850  0.923077     1.000
# 3.1 (1)  0.675000  0.780488  0.800000  0.825000     0.900  0.897436     0.950
# 3.2 (2)  0.414634  0.463415  0.585366  0.625000     0.650  0.400000     0.500
# 3.3 (4)  0.317073  0.536585  0.195122  0.525000     0.500  0.725000     0.650
# 3.4 (2)  0.500000  0.609756  0.800000  0.875000     0.775  0.897436     0.825
# 4.1 (1)  0.170732  0.195122  0.365854  0.525000     0.575  0.450000     0.475
# 4.2 (3)  0.634146  0.682927  0.292683  0.700000     0.575  0.875000     0.875
# 4.3 (3)  0.425000  0.829268  0.675000  0.725000     0.750  0.794872     0.825
# 4.4 (4)  0.250000  0.536585  0.525000  0.600000     0.475  0.794872     0.800
#
# date     20220510  20220511  20220512  20220516  cage
# subject
# 1.1      0.687500     0.500       NaN  0.634146     1
# 1.2      0.775000     0.800     0.325  0.700000     2
# 1.3      0.725000     0.700     0.450  0.500000     2
# 1.4      0.587500     0.425       NaN  0.439024     1
# 2.1      0.600000     0.775     0.400  0.550000     2
# 2.2      0.662500     0.300       NaN  0.585366     1
# 2.3      0.837500     0.750       NaN  0.853659     1
# 2.4      0.875000     0.900     0.800  0.725000     2
# 3.1 (1)  0.853659     0.925     0.925       NaN     4
# 3.2 (2)  0.390244     0.525     0.575       NaN     3
# 3.3 (4)  0.682927     0.450     0.550       NaN     3
# 3.4 (2)  0.804878     0.850     0.800       NaN     4
# 4.1 (1)  0.560976     0.625     0.375       NaN     3
# 4.2 (3)  0.853659     0.825     0.725       NaN     3
# 4.3 (3)  0.731707     0.750     0.850       NaN     4
# 4.4 (4)  0.682927     0.825     0.850       NaN     4

# %%
less_than_10_latency_df.to_csv(os.path.join(pivot_plot_output_directory, "less_than_10_seconds_latencies_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
less_than_10_latency_df.to_excel(os.path.join(pivot_plot_output_directory, "less_than_10_seconds_latencies_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %% [markdown]
# # Plotting the latencies

# %% [markdown]
# - We will plot a line for each subject. With the X-axis being the days since the first session. And the Y-axis is the latency values averaged across all the trials for one recording session
# - Grouping all the rows with the same subject and date(aka, all the trials in one session). And then getting the mean for each value

# %%
grouped_averaged_first_porty_entry_dataframe = concatted_first_and_last_porty_entry_dataframe.groupby(by=["file_path", "date", "subject"]).mean()

# %%
grouped_averaged_first_porty_entry_dataframe.head()
# Out:
#                                                                      current_tone_time  \
# file_path                                          date     subject
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.1             675.676667
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.4             675.676667
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.2             675.676667
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.3             675.676667
# ./data/timestamp_dataframes/2022-05-03_12h44m_S... 20220503 2.1              60.010000
#
#                                                                      first_port_entry_after_tone  \
# file_path                                          date     subject
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.1                       717.894667
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.4                       737.022000
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.2                       718.850000
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.3                       753.886000
# ./data/timestamp_dataframes/2022-05-03_12h44m_S... 20220503 2.1                              NaN
#
#                                                                      port_exit_after_first_port_entry_after_tone  \
# file_path                                          date     subject
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.1                                       718.904667
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.4                                       737.790667
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.2                                       720.442667
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.3                                       708.698571
# ./data/timestamp_dataframes/2022-05-03_12h44m_S... 20220503 2.1                                              NaN
#
#                                                                      last_port_entry_before_tone  \
# file_path                                          date     subject
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.1                       708.214615
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.4                       613.392000
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.2                       723.873077
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.3                       622.696000
# ./data/timestamp_dataframes/2022-05-03_12h44m_S... 20220503 2.1                         0.000000
#
#                                                                      port_exit_after_last_port_entry_before_tone  \
# file_path                                          date     subject
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.1                                       708.941538
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.4                                       614.831333
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.2                                       726.491538
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.3                                       624.028000
# ./data/timestamp_dataframes/2022-05-03_12h44m_S... 20220503 2.1                                              NaN
#
#                                                                        latency  \
# file_path                                          date     subject
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.1      42.218000
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.4      61.345333
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.2      43.173333
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.3      78.209333
# ./data/timestamp_dataframes/2022-05-03_12h44m_S... 20220503 2.1            NaN
#
#                                                                      latency_adjusted_greater_than_30  \
# file_path                                          date     subject
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.1                             19.980000
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.4                             22.285333
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.2                             23.155333
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.3                             28.618000
# ./data/timestamp_dataframes/2022-05-03_12h44m_S... 20220503 2.1                                   NaN
#
#                                                                      overlapping_port_entry_with_tone  \
# file_path                                          date     subject
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.1                              0.000000
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.4                              0.066667
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.2                              0.066667
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.3                              0.066667
# ./data/timestamp_dataframes/2022-05-03_12h44m_S... 20220503 2.1                              0.000000
#
#                                                                      latency_adjusted_overlap  \
# file_path                                          date     subject
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.1                     19.980000
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.4                     21.607333
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.2                     21.155333
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.3                     26.618000
# ./data/timestamp_dataframes/2022-05-03_12h44m_S... 20220503 2.1                           NaN
#
#                                                                      latency_less_than_10_seconds  \
# file_path                                          date     subject
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.1                          0.333333
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.4                          0.200000
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.2                          0.200000
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.3                          0.066667
# ./data/timestamp_dataframes/2022-05-03_12h44m_S... 20220503 2.1                          0.000000
#
#                                                                      overlap_adjusted_latency_less_than_10_seconds
# file_path                                          date     subject
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.1                                           0.333333
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 1.4                                           0.266667
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.2                                           0.266667
# ./data/timestamp_dataframes/2022-05-03_10h38m_S... 20220503 2.3                                           0.133333
# ./data/timestamp_dataframes/2022-05-03_12h44m_S... 20220503 2.1                                           0.000000

# %% [markdown]
# - Resetting the index so that we can use the data as a value

# %%
grouped_averaged_first_porty_entry_dataframe = grouped_averaged_first_porty_entry_dataframe.reset_index()

# %%
grouped_averaged_first_porty_entry_dataframe.head()
# Out:
#                                            file_path      date subject  \
# 0  ./data/timestamp_dataframes/2022-05-03_10h38m_...  20220503     1.1
# 1  ./data/timestamp_dataframes/2022-05-03_10h38m_...  20220503     1.4
# 2  ./data/timestamp_dataframes/2022-05-03_10h38m_...  20220503     2.2
# 3  ./data/timestamp_dataframes/2022-05-03_10h38m_...  20220503     2.3
# 4  ./data/timestamp_dataframes/2022-05-03_12h44m_...  20220503     2.1
#
#    current_tone_time  first_port_entry_after_tone  \
# 0         675.676667                   717.894667
# 1         675.676667                   737.022000
# 2         675.676667                   718.850000
# 3         675.676667                   753.886000
# 4          60.010000                          NaN
#
#    port_exit_after_first_port_entry_after_tone  last_port_entry_before_tone  \
# 0                                   718.904667                   708.214615
# 1                                   737.790667                   613.392000
# 2                                   720.442667                   723.873077
# 3                                   708.698571                   622.696000
# 4                                          NaN                     0.000000
#
#    port_exit_after_last_port_entry_before_tone    latency  \
# 0                                   708.941538  42.218000
# 1                                   614.831333  61.345333
# 2                                   726.491538  43.173333
# 3                                   624.028000  78.209333
# 4                                          NaN        NaN
#
#    latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# 0                         19.980000                          0.000000
# 1                         22.285333                          0.066667
# 2                         23.155333                          0.066667
# 3                         28.618000                          0.066667
# 4                               NaN                          0.000000
#
#    latency_adjusted_overlap  latency_less_than_10_seconds  \
# 0                 19.980000                      0.333333
# 1                 21.607333                      0.200000
# 2                 21.155333                      0.200000
# 3                 26.618000                      0.066667
# 4                       NaN                      0.000000
#
#    overlap_adjusted_latency_less_than_10_seconds
# 0                                       0.333333
# 1                                       0.266667
# 2                                       0.266667
# 3                                       0.133333
# 4                                       0.000000

# %% [markdown]
# - Turning the date column which is a string, into an integer
#     - This will allow us to use the date as the X-axis for plotting

# %%
grouped_averaged_first_porty_entry_dataframe["date_int"] = grouped_averaged_first_porty_entry_dataframe["date"].astype(int)

# %%
grouped_averaged_first_porty_entry_dataframe.head()
# Out:
#                                            file_path      date subject  \
# 0  ./data/timestamp_dataframes/2022-05-03_10h38m_...  20220503     1.1
# 1  ./data/timestamp_dataframes/2022-05-03_10h38m_...  20220503     1.4
# 2  ./data/timestamp_dataframes/2022-05-03_10h38m_...  20220503     2.2
# 3  ./data/timestamp_dataframes/2022-05-03_10h38m_...  20220503     2.3
# 4  ./data/timestamp_dataframes/2022-05-03_12h44m_...  20220503     2.1
#
#    current_tone_time  first_port_entry_after_tone  \
# 0         675.676667                   717.894667
# 1         675.676667                   737.022000
# 2         675.676667                   718.850000
# 3         675.676667                   753.886000
# 4          60.010000                          NaN
#
#    port_exit_after_first_port_entry_after_tone  last_port_entry_before_tone  \
# 0                                   718.904667                   708.214615
# 1                                   737.790667                   613.392000
# 2                                   720.442667                   723.873077
# 3                                   708.698571                   622.696000
# 4                                          NaN                     0.000000
#
#    port_exit_after_last_port_entry_before_tone    latency  \
# 0                                   708.941538  42.218000
# 1                                   614.831333  61.345333
# 2                                   726.491538  43.173333
# 3                                   624.028000  78.209333
# 4                                          NaN        NaN
#
#    latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# 0                         19.980000                          0.000000
# 1                         22.285333                          0.066667
# 2                         23.155333                          0.066667
# 3                         28.618000                          0.066667
# 4                               NaN                          0.000000
#
#    latency_adjusted_overlap  latency_less_than_10_seconds  \
# 0                 19.980000                      0.333333
# 1                 21.607333                      0.200000
# 2                 21.155333                      0.200000
# 3                 26.618000                      0.066667
# 4                       NaN                      0.000000
#
#    overlap_adjusted_latency_less_than_10_seconds  date_int
# 0                                       0.333333  20220503
# 1                                       0.266667  20220503
# 2                                       0.266667  20220503
# 3                                       0.133333  20220503
# 4                                       0.000000  20220503

# %% [markdown]
# - Adding the cage information
#     - We will make one plot for each cage

# %%
grouped_averaged_first_porty_entry_dataframe["cage"] = grouped_averaged_first_porty_entry_dataframe["subject"].map(subject_to_cage).astype(int)

# %%
grouped_averaged_first_porty_entry_dataframe.head()
# Out:
#                                            file_path      date subject  \
# 0  ./data/timestamp_dataframes/2022-05-03_10h38m_...  20220503     1.1
# 1  ./data/timestamp_dataframes/2022-05-03_10h38m_...  20220503     1.4
# 2  ./data/timestamp_dataframes/2022-05-03_10h38m_...  20220503     2.2
# 3  ./data/timestamp_dataframes/2022-05-03_10h38m_...  20220503     2.3
# 4  ./data/timestamp_dataframes/2022-05-03_12h44m_...  20220503     2.1
#
#    current_tone_time  first_port_entry_after_tone  \
# 0         675.676667                   717.894667
# 1         675.676667                   737.022000
# 2         675.676667                   718.850000
# 3         675.676667                   753.886000
# 4          60.010000                          NaN
#
#    port_exit_after_first_port_entry_after_tone  last_port_entry_before_tone  \
# 0                                   718.904667                   708.214615
# 1                                   737.790667                   613.392000
# 2                                   720.442667                   723.873077
# 3                                   708.698571                   622.696000
# 4                                          NaN                     0.000000
#
#    port_exit_after_last_port_entry_before_tone    latency  \
# 0                                   708.941538  42.218000
# 1                                   614.831333  61.345333
# 2                                   726.491538  43.173333
# 3                                   624.028000  78.209333
# 4                                          NaN        NaN
#
#    latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# 0                         19.980000                          0.000000
# 1                         22.285333                          0.066667
# 2                         23.155333                          0.066667
# 3                         28.618000                          0.066667
# 4                               NaN                          0.000000
#
#    latency_adjusted_overlap  latency_less_than_10_seconds  \
# 0                 19.980000                      0.333333
# 1                 21.607333                      0.200000
# 2                 21.155333                      0.200000
# 3                 26.618000                      0.066667
# 4                       NaN                      0.000000
#
#    overlap_adjusted_latency_less_than_10_seconds  date_int  cage
# 0                                       0.333333  20220503     1
# 1                                       0.266667  20220503     1
# 2                                       0.266667  20220503     1
# 3                                       0.133333  20220503     1
# 4                                       0.000000  20220503     2

# %% [markdown]
# - Plotting the adjusted latency

# %%
pivot_plot_output_directory = "./data/plots/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
pivot_plot_output_directory
# Out:
# './data/subject_rows_with_date_columns_dataframes/cage_1_2_3_4_date_20220503_20220516'

# %%
os.makedirs(pivot_plot_output_directory, exist_ok=True)

# %% [markdown]
# # EDIT FROM HERE

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["date_int"] - subject_df["date_int"].min() + 1, subject_df["latency_adjusted_greater_than_30"], '-o', label=subject)

    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 30)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("The Days After the First Session")
    ax.set_ylabel("Adjusted Average Latency of First Entry to Tone Onset")
    ax.set_title("Latency of Port Entry to Tone: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    plt.savefig("./data/plots/average_latency_plots/average_port_entry_latency_cage_{}_date_{}_{}.png".format(cage))

# %% [markdown]
# - Plotting the ratio of latencies that are less than 10 seconds

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["date_int"] - subject_df["date_int"].min() + 1, subject_df["latency_less_than_10_seconds"], '-o', label=subject)

    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 1)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("The Days After the First Session")
    ax.set_ylabel("Proportion of Latencies")
    ax.set_title("Less Than 10 Seconds Latencies from Tone Onset: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    plt.savefig("./data/plots/proportion_of_latencies_less_than_10_seconds/less_than_10_seconds_latency_proportion_cage_{}_date_{}_{}.png".format(cage))

# %% [markdown]
# # Calculate Average Latency Across Time

# %% [markdown]
# - Goals:
#     - Calculate first port entry and exit before and after the tone plays
#     - See what the average duraction of being inside the port is
#     - See how often the mice are already in the port

# %% [markdown]
# # Plotting the Overlap

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["date_int"] - subject_df["date_int"].min() + 1, subject_df["overlapping_port_entry_with_tone"], '-o', label=subject)

    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 1)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("The Days After the First Session")
    ax.set_ylabel("Proportion of Latencies")
    ax.set_title("Port Entries/Exit that Overlap with Tone Onset: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    plt.savefig("./data/plots/overlap_ratios/overlap_ratios_cage_{}_date_{}_{}.png".format(cage))

# %% [markdown]
# # Plotting the Adjusted Latencies That are Overlapped

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["date_int"] - subject_df["date_int"].min() + 1, subject_df["latency_adjusted_overlap"], '-o', label=subject)

    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 30)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("The Days After the First Session")
    ax.set_ylabel("Adjusted Average Latency of First Entry to Tone Onset")
    ax.set_title("Latency of Port Entry to Tone Adjusted for Overlap: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    plt.savefig("./data/plots/overlap_adjusted_latencies/overlap_adjusted_latencies_cage_{}_date_{}_{}.png".format(cage))

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["date_int"] - subject_df["date_int"].min() + 1, subject_df["overlap_adjusted_latency_less_than_10_seconds"], '-o', label=subject)

    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 1)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("The Days After the First Session")
    ax.set_ylabel("Proportion of Latencies")
    ax.set_title("Overlap Adjusted Less Than 10sec Latencies from Tone: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    plt.savefig("./data/plots/overlap_adjusted_proportion_of_latencies_less_than_10_seconds/overlap_adjusted_proportion_of_latencies_less_than_10_seconds_cage_{}_date_{}_{}.png".format(cage))
