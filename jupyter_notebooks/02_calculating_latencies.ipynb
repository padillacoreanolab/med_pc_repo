# %% [markdown]
# # MED-PC Calculating Latencies

# %% [markdown]
# ## Importing the Python Libraries

# %%
import sys
import glob
from collections import defaultdict
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from medpc2excel.medpc_read import medpc_read

# %%
# setting path
sys.path.append('../src')

# %%
# All the libraries that were created for this repository
import extract.dataframe
import processing.tone
import extract.metadata

# %%
# Increase size of plot in jupyter

plt.rcParams["figure.figsize"] = (10,6)

# %% [markdown]
# # Loading in Recording and Metadata from Previous Notebook

# %% [markdown]
# # NOTE: If you changed the directory of where the MED-PC recording dataframes, then you must change the directories in the following paths

# %% [markdown]
# - This will get all the files in each specified path

# %%
concatted_medpc_files = glob.glob("./proc/extracted_recording_data_and_metadata/*/MEDPC_recording_cage_*.csv")
metadata_files = glob.glob("./proc/extracted_recording_data_and_metadata/*/metadata_cage_*.csv")
recording_and_metadata_files = glob.glob("./proc/extracted_recording_data_and_metadata/*/recording_and_metadata_cage_*.csv")

# %% [markdown]
# # NOTE: If there is more than one MED-PC recording dataframes, then you must manually change the path in the `pd.read_csv()` for the corresponding variables. Verify if this is the correct file that you want to use

# %%
metadata_files[0]
# Out:
# './proc/extracted_recording_data_and_metadata/cage_1_2_3_4_date_20220504_20220512/metadata_cage_1_2_3_4_date_20220504_20220512.csv'

# %%
concatted_medpc_files[0]
# Out:
# './proc/extracted_recording_data_and_metadata/cage_1_2_3_4_date_20220504_20220512/MEDPC_recording_cage_1_2_3_4_date_20220504_20220512.csv'

# %%
recording_and_metadata_files[0]
# Out:
# './proc/extracted_recording_data_and_metadata/cage_1_2_3_4_date_20220504_20220512/recording_and_metadata_cage_1_2_3_4_date_20220504_20220512.csv'

# %%
metadata_df = pd.read_csv(metadata_files[0], index_col=0)
concatted_medpc_df = pd.read_csv(concatted_medpc_files[0], index_col=0)
recording_and_metadata_df = pd.read_csv(recording_and_metadata_files[0], index_col=0)
# Out:
# /tmp/ipykernel_912151/169435060.py:3: DtypeWarning: Columns (10,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   recording_and_metadata_df = pd.read_csv(recording_and_metadata_files[0], index_col=0)

# %% [markdown]
# - The Dataframe the contains the metadata(columns) of each recording file(rows)
#     - We will mostly use this to get the cage number for each subject

# %%
metadata_df.head()
# Out:
#                                                index  \
# 0  ./example_recordings/2022-05-06_12h59m_Subject...
# 1  ./example_recordings/2022-05-06_08h37m_Subject...
# 2  ./example_recordings/2022-05-10_14h40m_Subject...
# 3  ./example_recordings/2022-05-06_12h59m_Subject...
# 4  ./example_recordings/2022-05-04_08h43m_Subject...
#
#                                                 File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-05-06_12h59m_Subject 3.4 (...   05/06/22  05/06/22
# 1   C:\MED-PC\Data\2022-05-06_08h37m_Subject 2.3.txt   05/06/22  05/06/22
# 2  C:\MED-PC\Data\2022-05-10_14h40m_Subject 4.3 (...   05/10/22  05/10/22
# 3  C:\MED-PC\Data\2022-05-06_12h59m_Subject 4.3 (...   05/06/22  05/06/22
# 4   C:\MED-PC\Data\2022-05-04_08h43m_Subject 2.3.txt   05/04/22  05/04/22
#
#    Subject      Experiment   Group  Box Start Time  End Time  \
# 0  3.4 (2)  Pilot of Pilot  Cage 4    1   12:59:58  14:02:38
# 1      2.3  Pilot of Pilot  Cage 1    1   08:37:09  09:53:25
# 2  4.3 (3)  Pilot of Pilot  Cage 4    2   14:40:24  15:43:18
# 3  4.3 (3)  Pilot of Pilot  Cage 4    2   12:59:58  14:02:38
# 4      2.3  Pilot of Pilot  Cage 1    3   08:43:11  09:54:22
#
#                                          MSN  cage
# 0  levelNP_CS_reward_laserepochON1st_noshock     4
# 1  levelNP_CS_reward_laserepochON1st_noshock     1
# 2  levelNP_CS_reward_laserepochON1st_noshock     4
# 3  levelNP_CS_reward_laserepochON1st_noshock     4
# 4  levelNP_CS_reward_laserepochON1st_noshock     1

# %% [markdown]
# - The Dataframe the contains the recording data for all the files.
#     - The 1st row is the first data entries for each type of data(with the type being specified by the column label). This does not mean that all these are related or occured for the same trial. i.e. There can be many port entries and exits for a subject before and after a tone is played.
#     - Each recording session will usually have a few thousand rows(although, most of of the columns will probably be blank by the end). And then after the last row of one session, the next row will be the next session with a different `file_path`

# %%
concatted_medpc_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0         12.34           64.0      399.0           0.0              60.01
# 1         14.60          144.0      399.0           0.0             140.01
# 2         23.95          234.0      399.0           0.0             230.01
# 3         31.83          314.0      399.0           0.0             310.01
# 4         31.99          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (B)shockintensity      date  subject  \
# 0        12.39        1.0                0.0  20220506  3.4 (2)
# 1        14.79        1.0                0.0  20220506  3.4 (2)
# 2        24.88        1.0                0.0  20220506  3.4 (2)
# 3        31.90        1.0                0.0  20220506  3.4 (2)
# 4        32.09        1.0                0.0  20220506  3.4 (2)
#
#                                            file_path
# 0  ./example_recordings/2022-05-06_12h59m_Subject...
# 1  ./example_recordings/2022-05-06_12h59m_Subject...
# 2  ./example_recordings/2022-05-06_12h59m_Subject...
# 3  ./example_recordings/2022-05-06_12h59m_Subject...
# 4  ./example_recordings/2022-05-06_12h59m_Subject...

# %% [markdown]
# - This dataframe combines the recording data and metadata dataframes. This is done by using the subject ID as a common column to merge together off of.

# %%
recording_and_metadata_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0         12.34           64.0      399.0           0.0              60.01
# 1         14.60          144.0      399.0           0.0             140.01
# 2         23.95          234.0      399.0           0.0             230.01
# 3         31.83          314.0      399.0           0.0             310.01
# 4         31.99          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (B)shockintensity      date  subject  ...  \
# 0        12.39        1.0                0.0  20220506  3.4 (2)  ...
# 1        14.79        1.0                0.0  20220506  3.4 (2)  ...
# 2        24.88        1.0                0.0  20220506  3.4 (2)  ...
# 3        31.90        1.0                0.0  20220506  3.4 (2)  ...
# 4        32.09        1.0                0.0  20220506  3.4 (2)  ...
#
#   Start Date  End Date  Subject      Experiment   Group Box Start Time  \
# 0   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 1   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 2   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 3   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 4   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
#
#    End Time                                        MSN cage
# 0  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 1  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 2  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 3  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 4  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Getting the Cage Numbers and the Dates for the file names

# %% [markdown]
# - Seeing if any rows have NaN values for the cages

# %%
metadata_df[pd.isna(metadata_df["cage"])]
# Out:
# Empty DataFrame
# Columns: [index, File, Start Date, End Date, Subject, Experiment, Group, Box, Start Time, End Time, MSN, cage]
# Index: []

# %% [markdown]
# - Dropping the NaN values so we can get the cage numbers

# %%
metadata_df = metadata_df.dropna(subset=["cage"])

# %%
# removing blank spaces
cage_numbers = [str(int(number)) for number in metadata_df["cage"].unique() if number is not np.nan]
# sorting numbers
cage_numbers = sorted(cage_numbers)
cage_numbers_for_title = "_".join(cage_numbers)

# %%
cage_numbers_for_title
# Out:
# '1_2_3_4'

# %%
# Getting the first and last recording date to get a range
earliest_date = concatted_medpc_df["date"].min()
latest_date = concatted_medpc_df["date"].max()

# %%
earliest_date
# Out:
# 20220504

# %%
latest_date
# Out:
# 20220512

# %% [markdown]
# # Getting the First Port Entry After Each Tone

# %% [markdown]
# - Getting all the rows that correspond to one of the files paths. This will be the equivalent of getting all the rows for one session

# %%
example_one_session_recording_df = recording_and_metadata_df[recording_and_metadata_df["file_path"] == recording_and_metadata_df["file_path"].unique()[0]
]

# %% [markdown]
# - Everything looks normal enough

# %%
example_one_session_recording_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0         12.34           64.0      399.0           0.0              60.01
# 1         14.60          144.0      399.0           0.0             140.01
# 2         23.95          234.0      399.0           0.0             230.01
# 3         31.83          314.0      399.0           0.0             310.01
# 4         31.99          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (B)shockintensity      date  subject  ...  \
# 0        12.39        1.0                0.0  20220506  3.4 (2)  ...
# 1        14.79        1.0                0.0  20220506  3.4 (2)  ...
# 2        24.88        1.0                0.0  20220506  3.4 (2)  ...
# 3        31.90        1.0                0.0  20220506  3.4 (2)  ...
# 4        32.09        1.0                0.0  20220506  3.4 (2)  ...
#
#   Start Date  End Date  Subject      Experiment   Group Box Start Time  \
# 0   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 1   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 2   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 3   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 4   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
#
#    End Time                                        MSN cage
# 0  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 1  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 2  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 3  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 4  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
#
# [5 rows x 23 columns]

# %% [markdown]
# - `(S)CSpresentation` is the time that the tone starts playing. MED-PC starts inputting in random numbers that are in the 1000's. So we will remove these

# %%
example_one_session_recording_df[50:60]
# Out:
#     (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 50        438.69            NaN        NaN           0.0             9000.0
# 51        446.71            NaN        NaN           0.0            12000.0
# 52        452.60            NaN        NaN           0.0             9000.0
# 53        460.11            NaN        NaN           0.0             8500.0
# 54        464.04            NaN        NaN           0.0             9000.0
# 55        475.64            NaN        NaN           0.0             9500.0
# 56        484.23            NaN        NaN           0.0            12000.0
# 57        487.74            NaN        NaN           0.0             8000.0
# 58        495.85            NaN        NaN           0.0             9500.0
# 59        505.47            NaN        NaN           0.0             8000.0
#
#     (N)Portexit  (K)CStype  (B)shockintensity      date  subject  ...  \
# 50       439.62        0.0                0.0  20220506  3.4 (2)  ...
# 51       447.92        0.0                0.0  20220506  3.4 (2)  ...
# 52       453.28        0.0                0.0  20220506  3.4 (2)  ...
# 53       461.21        0.0                0.0  20220506  3.4 (2)  ...
# 54       464.49        0.0                0.0  20220506  3.4 (2)  ...
# 55       476.41        0.0                0.0  20220506  3.4 (2)  ...
# 56       484.53        0.0                0.0  20220506  3.4 (2)  ...
# 57       489.12        0.0                0.0  20220506  3.4 (2)  ...
# 58       499.31        0.0                0.0  20220506  3.4 (2)  ...
# 59       507.17        0.0                0.0  20220506  3.4 (2)  ...
#
#    Start Date  End Date  Subject      Experiment   Group Box Start Time  \
# 50   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 51   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 52   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 53   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 54   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 55   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 56   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 57   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 58   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 59   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
#
#     End Time                                        MSN cage
# 50  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 51  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 52  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 53  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 54  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 55  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 56  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 57  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 58  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 59  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
#
# [10 rows x 23 columns]

# %% [markdown]
# - `(S)CSpresentation` then starts adding blanks(NaN) so we will remove these too

# %%
example_one_session_recording_df.tail()
# Out:
#       (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 2536           NaN            NaN        NaN           NaN                NaN
# 2537           NaN            NaN        NaN           NaN                NaN
# 2538           NaN            NaN        NaN           NaN                NaN
# 2539           NaN            NaN        NaN           NaN                NaN
# 2540           NaN            NaN        NaN           NaN                NaN
#
#       (N)Portexit  (K)CStype  (B)shockintensity      date  subject  ...  \
# 2536          NaN        1.0                NaN  20220506  3.4 (2)  ...
# 2537          NaN        1.0                NaN  20220506  3.4 (2)  ...
# 2538          NaN        1.0                NaN  20220506  3.4 (2)  ...
# 2539          NaN        1.0                NaN  20220506  3.4 (2)  ...
# 2540          NaN        1.0                NaN  20220506  3.4 (2)  ...
#
#      Start Date  End Date  Subject      Experiment   Group Box Start Time  \
# 2536   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 2537   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 2538   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 2539   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
# 2540   05/06/22  05/06/22  3.4 (2)  Pilot of Pilot  Cage 4   1   12:59:58
#
#       End Time                                        MSN cage
# 2536  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 2537  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 2538  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 2539  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
# 2540  14:02:38  levelNP_CS_reward_laserepochON1st_noshock    4
#
# [5 rows x 23 columns]

# %% [markdown]
# - Getting the tones that were actually used for the recordings

# %%
example_one_session_valid_tones = processing.tone.get_valid_tones(example_one_session_recording_df["(S)CSpresentation"])

# %%
example_one_session_valid_tones
# Out:
# 0       60.01
# 1      140.01
# 2      230.01
# 3      310.01
# 4      385.01
# 5      485.01
# 6      580.01
# 7      670.01
# 8      750.01
# 9      840.01
# 10     940.01
# 11    1030.01
# 12    1150.01
# 13    1240.01
# 14    1325.01
# 15    1415.01
# 16    1510.01
# 17    1630.01
# 18    1710.01
# 19    1805.01
# 20    1885.01
# 21    1975.01
# 22    2055.01
# 23    2130.01
# 24    2230.01
# 25    2325.01
# 26    2415.01
# 27    2495.01
# 28    2585.01
# 29    2685.01
# 30    2775.01
# 31    2895.01
# 32    2985.01
# 33    3070.01
# 34    3160.01
# 35    3255.01
# 36    3345.01
# 37    3425.01
# 38    3515.01
# 39    3615.01
# Name: (S)CSpresentation, dtype: float64

# %% [markdown]
# - With these tone playing times, we will get the first port entry that comes after the tone playing time
#     - This was done by getting all the port entries that came after the tone. And then getting the port entry time that was earliest in time(aka smallest number)

# %%
processing.tone.get_first_port_entries_after_tone(tone_pd_series=example_one_session_valid_tones, port_entries_pd_series=example_one_session_recording_df["(P)Portentry"], port_exits_pd_series=example_one_session_recording_df["(N)Portexit"])
# Out:
#     current_tone_time  first_port_entry_after_tone  \
# 0               60.01                        69.00
# 1              140.01                       148.27
# 2              230.01                       231.91
# 3              310.01                       320.97
# 4              385.01                       394.75
# 5              485.01                       487.74
# 6              580.01                       584.00
# 7              670.01                       676.26
# 8              750.01                       777.83
# 9              840.01                       840.06
# 10             940.01                       943.30
# 11            1030.01                      1035.05
# 12            1150.01                      1224.44
# 13            1240.01                      1253.35
# 14            1325.01                      1325.78
# 15            1415.01                      1419.19
# 16            1510.01                      1516.06
# 17            1630.01                      1632.25
# 18            1710.01                      1713.50
# 19            1805.01                      1806.80
# 20            1885.01                      1889.58
# 21            1975.01                      1975.87
# 22            2055.01                      2055.51
# 23            2130.01                      2192.23
# 24            2230.01                      2230.20
# 25            2325.01                      2332.53
# 26            2415.01                      2420.74
# 27            2495.01                      2495.05
# 28            2585.01                      2586.63
# 29            2685.01                      2685.35
# 30            2775.01                      2777.86
# 31            2895.01                      2898.99
# 32            2985.01                      2986.95
# 33            3070.01                      3071.11
# 34            3160.01                      3161.54
# 35            3255.01                      3256.06
# 36            3345.01                      3348.54
# 37            3425.01                      3430.63
# 38            3515.01                      3515.62
# 39            3615.01                      3615.67
#
#     port_exit_after_first_port_entry_after_tone
# 0                                         73.66
# 1                                        151.69
# 2                                        233.40
# 3                                        327.71
# 4                                        398.05
# 5                                        489.12
# 6                                        598.64
# 7                                        676.30
# 8                                        782.02
# 9                                        841.92
# 10                                       944.29
# 11                                      1045.48
# 12                                      1229.68
# 13                                      1255.06
# 14                                      1326.30
# 15                                      1443.29
# 16                                      1530.28
# 17                                      1633.57
# 18                                      1714.08
# 19                                      1807.30
# 20                                      1890.21
# 21                                      1976.10
# 22                                      2056.25
# 23                                      2195.37
# 24                                      2231.21
# 25                                      2334.20
# 26                                      2422.72
# 27                                      2495.64
# 28                                      2587.45
# 29                                      2685.98
# 30                                      2778.77
# 31                                      2903.65
# 32                                      2987.99
# 33                                      3072.07
# 34                                      3161.57
# 35                                      3256.61
# 36                                      3349.14
# 37                                      3433.94
# 38                                      3516.01
# 39                                      3616.30

# %% [markdown]
# - Getting the first port entry times for all the sessions

# %%
concatted_first_porty_entry_dataframe = processing.tone.get_concatted_first_porty_entry_after_tone_dataframe(concatted_medpc_df=concatted_medpc_df)

# %%
concatted_first_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        69.00
# 1             140.01                       148.27
# 2             230.01                       231.91
# 3             310.01                       320.97
# 4             385.01                       394.75
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        73.66
# 1                                       151.69
# 2                                       233.40
# 3                                       327.71
# 4                                       398.05
#
#                                            file_path      date  subject
# 0  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 1  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 2  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 3  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 4  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)

# %%
concatted_first_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        69.00
# 1             140.01                       148.27
# 2             230.01                       231.91
# 3             310.01                       320.97
# 4             385.01                       394.75
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        73.66
# 1                                       151.69
# 2                                       233.40
# 3                                       327.71
# 4                                       398.05
#
#                                            file_path      date  subject
# 0  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 1  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 2  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 3  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 4  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)

# %% [markdown]
# # Getting the Last Port Entry Before the Tone

# %% [markdown]
# - We will do the same, but get the port entries that happened before the tone

# %%
port_entries_pd_series = example_one_session_recording_df["(P)Portentry"]
port_exit_pd_series = example_one_session_recording_df["(N)Portexit"]

# %% [markdown]
# - Example run for one session

# %%
example_last_port_entries_before_tone = processing.tone.get_last_port_entries_before_tone(tone_pd_series=example_one_session_valid_tones, port_entries_pd_series=port_entries_pd_series, port_exits_pd_series=port_exit_pd_series)

# %%
example_last_port_entries_before_tone
# Out:
#     current_tone_time  last_port_entry_before_tone  \
# 0               60.01                        54.90
# 1              140.01                       125.14
# 2              230.01                       224.43
# 3              310.01                       298.91
# 4              385.01                       384.15
# 5              485.01                       484.23
# 6              580.01                       578.18
# 7              670.01                       667.64
# 8              750.01                       734.83
# 9              840.01                       826.15
# 10             940.01                       938.94
# 11            1030.01                      1019.19
# 12            1150.01                      1129.43
# 13            1240.01                      1237.63
# 14            1325.01                      1322.93
# 15            1415.01                      1413.21
# 16            1510.01                      1482.64
# 17            1630.01                      1628.06
# 18            1710.01                      1707.54
# 19            1805.01                      1799.74
# 20            1885.01                      1878.58
# 21            1975.01                      1973.96
# 22            2055.01                      2050.73
# 23            2130.01                      2093.55
# 24            2230.01                      2203.14
# 25            2325.01                      2256.55
# 26            2415.01                      2408.09
# 27            2495.01                      2481.02
# 28            2585.01                      2579.63
# 29            2685.01                      2670.39
# 30            2775.01                      2770.42
# 31            2895.01                      2893.25
# 32            2985.01                      2979.03
# 33            3070.01                      3063.86
# 34            3160.01                      3158.72
# 35            3255.01                      3243.97
# 36            3345.01                      3338.56
# 37            3425.01                      3421.11
# 38            3515.01                      3508.76
# 39            3615.01                      3603.03
#
#     port_exit_after_last_port_entry_before_tone
# 0                                         55.73
# 1                                        126.71
# 2                                        225.00
# 3                                        299.28
# 4                                        384.46
# 5                                        484.53
# 6                                        579.04
# 7                                        668.20
# 8                                        734.87
# 9                                        826.57
# 10                                       939.65
# 11                                      1020.65
# 12                                      1131.25
# 13                                      1238.27
# 14                                      1323.39
# 15                                      1414.46
# 16                                      1483.10
# 17                                      1628.48
# 18                                      1707.95
# 19                                      1800.34
# 20                                      1880.22
# 21                                      1975.69
# 22                                      2051.14
# 23                                      2094.05
# 24                                      2203.72
# 25                                      2257.74
# 26                                      2409.25
# 27                                      2481.40
# 28                                      2580.30
# 29                                      2671.16
# 30                                      2771.00
# 31                                      2893.55
# 32                                      2979.41
# 33                                      3064.24
# 34                                      3159.19
# 35                                      3244.86
# 36                                      3338.85
# 37                                      3422.70
# 38                                      3509.13
# 39                                      3607.14

# %% [markdown]
# - Getting all the port entries that happen before the tone for all sessions

# %%
concatted_last_porty_entry_dataframe = processing.tone.get_concatted_last_porty_entry_before_tone_dataframe(concatted_medpc_df=concatted_medpc_df)

# %%
concatted_last_porty_entry_dataframe
# Out:
#       current_tone_time  last_port_entry_before_tone  \
# 0                 60.01                        54.90
# 1                140.01                       125.14
# 2                230.01                       224.43
# 3                310.01                       298.91
# 4                385.01                       384.15
# ...                 ...                          ...
# 5775            3160.01                      3152.67
# 5776            3255.01                      3245.72
# 5777            3345.01                      3344.18
# 5778            3425.01                      3423.33
# 5779            3515.01                      3509.84
#
#       port_exit_after_last_port_entry_before_tone  \
# 0                                           55.73
# 1                                          126.71
# 2                                          225.00
# 3                                          299.28
# 4                                          384.46
# ...                                           ...
# 5775                                      3155.50
# 5776                                      3246.89
# 5777                                      3345.95
# 5778                                      3424.15
# 5779                                      3509.97
#
#                                               file_path      date  subject
# 0     ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 1     ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 2     ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 3     ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 4     ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# ...                                                 ...       ...      ...
# 5775  ./example_recordings/2022-05-08_11h14m_Subject...  20220508      1.3
# 5776  ./example_recordings/2022-05-08_11h14m_Subject...  20220508      1.3
# 5777  ./example_recordings/2022-05-08_11h14m_Subject...  20220508      1.3
# 5778  ./example_recordings/2022-05-08_11h14m_Subject...  20220508      1.3
# 5779  ./example_recordings/2022-05-08_11h14m_Subject...  20220508      1.3
#
# [5780 rows x 6 columns]

# %% [markdown]
# ## Merging the dataframes for the first port entry after the tone and the last tone before the tone

# %%
# Combining it based on the tone times and the file path
concatted_first_and_last_porty_entry_dataframe = pd.merge(concatted_first_porty_entry_dataframe, concatted_last_porty_entry_dataframe,  how='left', left_on=['current_tone_time','file_path'], right_on = ['current_tone_time','file_path'], suffixes=('', '_y'))
# Dropping all columns that are duplicates
concatted_first_and_last_porty_entry_dataframe = concatted_first_and_last_porty_entry_dataframe.drop(concatted_first_and_last_porty_entry_dataframe.filter(regex='_y$').columns.tolist(), axis=1)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        69.00
# 1             140.01                       148.27
# 2             230.01                       231.91
# 3             310.01                       320.97
# 4             385.01                       394.75
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        73.66
# 1                                       151.69
# 2                                       233.40
# 3                                       327.71
# 4                                       398.05
#
#                                            file_path      date  subject  \
# 0  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 1  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 2  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 3  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 4  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone
# 0                        54.90                                        55.73
# 1                       125.14                                       126.71
# 2                       224.43                                       225.00
# 3                       298.91                                       299.28
# 4                       384.15                                       384.46

# %%
concatted_first_and_last_porty_entry_dataframe.shape
# Out:
# (5780, 8)

# %% [markdown]
# - Getting all the rows that have port entry to port exit time that overlaps with the tone playing
#     - This would be the port entries that came before the tone, but had a port exit after

# %%
port_entries_that_overlap = concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["port_exit_after_last_port_entry_before_tone"] >= concatted_first_and_last_porty_entry_dataframe["current_tone_time"]]

# %%
port_entries_that_overlap.head()
# Out:
#     current_tone_time  first_port_entry_after_tone  \
# 21            1975.01                      1975.87
# 47             670.01                       670.27
# 53            1240.01                      1242.58
# 62            2055.01                      2067.11
# 63            2130.01                      2134.46
#
#     port_exit_after_first_port_entry_after_tone  \
# 21                                      1976.10
# 47                                       670.89
# 53                                      1243.36
# 62                                      2073.44
# 63                                      2134.66
#
#                                             file_path      date  subject  \
# 21  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 47  ./example_recordings/2022-05-06_08h37m_Subject...  20220506      2.3
# 53  ./example_recordings/2022-05-06_08h37m_Subject...  20220506      2.3
# 62  ./example_recordings/2022-05-06_08h37m_Subject...  20220506      2.3
# 63  ./example_recordings/2022-05-06_08h37m_Subject...  20220506      2.3
#
#     last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone
# 21                      1973.96                                      1975.69
# 47                       669.88                                       670.17
# 53                      1239.45                                      1240.12
# 62                      2052.44                                      2055.04
# 63                      2129.20                                      2130.11

# %%
port_entries_that_overlap.shape
# Out:
# (1316, 8)

# %% [markdown]
# # Getting the Latency for Each Session of a Tone Playing

# %% [markdown]
# - To calculate latency, we would just subtract the time of the first port entry to that of the tone playing

# %%
concatted_first_and_last_porty_entry_dataframe["latency"] = concatted_first_porty_entry_dataframe["first_port_entry_after_tone"] - concatted_first_and_last_porty_entry_dataframe["current_tone_time"]

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        69.00
# 1             140.01                       148.27
# 2             230.01                       231.91
# 3             310.01                       320.97
# 4             385.01                       394.75
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        73.66
# 1                                       151.69
# 2                                       233.40
# 3                                       327.71
# 4                                       398.05
#
#                                            file_path      date  subject  \
# 0  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 1  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 2  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 3  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 4  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                        54.90                                        55.73
# 1                       125.14                                       126.71
# 2                       224.43                                       225.00
# 3                       298.91                                       299.28
# 4                       384.15                                       384.46
#
#    latency
# 0     8.99
# 1     8.26
# 2     1.90
# 3    10.96
# 4     9.74

# %% [markdown]
# - For all the latencies that are are greater than 30 seconds, we changed the latency to 30 seconds

# %%
concatted_first_and_last_porty_entry_dataframe["latency_adjusted_greater_than_30"] = concatted_first_and_last_porty_entry_dataframe["latency"].apply(lambda x: 30 if x >= 30 else x)

# %%
concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["latency"] >= 30].head()
# Out:
#      current_tone_time  first_port_entry_after_tone  \
# 12             1150.01                      1224.44
# 23             2130.01                      2192.23
# 109            2585.01                      2615.82
# 132             940.01                       982.59
# 154            2985.01                      3023.64
#
#      port_exit_after_first_port_entry_after_tone  \
# 12                                       1229.68
# 23                                       2195.37
# 109                                      2619.22
# 132                                       982.62
# 154                                      3027.26
#
#                                              file_path      date  subject  \
# 12   ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 23   ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 109  ./example_recordings/2022-05-10_14h40m_Subject...  20220510  4.3 (3)
# 132  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  4.3 (3)
# 154  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  4.3 (3)
#
#      last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 12                       1129.43                                      1131.25
# 23                       2093.55                                      2094.05
# 109                      2580.63                                      2581.81
# 132                       931.00                                       931.97
# 154                      2982.57                                      2984.74
#
#      latency  latency_adjusted_greater_than_30
# 12     74.43                              30.0
# 23     62.22                              30.0
# 109    30.81                              30.0
# 132    42.58                              30.0
# 154    38.63                              30.0

# %% [markdown]
# # Seeing which port entries and port exit durations overlap with the tone

# %% [markdown]
# - Making a column that states whether or not the last port entry before the tone has a port exit after the tone. This would mean that they are overlapping.

# %%
concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"] = concatted_first_and_last_porty_entry_dataframe.apply(lambda row: True if row["port_exit_after_last_port_entry_before_tone"] >= row["current_tone_time"] else False, axis=1)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        69.00
# 1             140.01                       148.27
# 2             230.01                       231.91
# 3             310.01                       320.97
# 4             385.01                       394.75
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        73.66
# 1                                       151.69
# 2                                       233.40
# 3                                       327.71
# 4                                       398.05
#
#                                            file_path      date  subject  \
# 0  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 1  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 2  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 3  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 4  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                        54.90                                        55.73
# 1                       125.14                                       126.71
# 2                       224.43                                       225.00
# 3                       298.91                                       299.28
# 4                       384.15                                       384.46
#
#    latency  latency_adjusted_greater_than_30  overlapping_port_entry_with_tone
# 0     8.99                              8.99                             False
# 1     8.26                              8.26                             False
# 2     1.90                              1.90                             False
# 3    10.96                             10.96                             False
# 4     9.74                              9.74                             False

# %% [markdown]
# - Comparing the latencies of the first port entry after the tone between these two groups:
#     - 1. Those with the last port entry before the tone that has a port exit after the tone("overlapping" group)
#     - 2. Those with the last port entry before the tone that has a port exit before the tone("nonoverlapping" group)

# %%
overlapping_df = concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"]]

# %%
non_overlapping_df = concatted_first_and_last_porty_entry_dataframe[~concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"]]

# %% [markdown]
# - Number of rows of overlapping and nonoverlapping last port entries before the tone

# %%
overlapping_df.shape
# Out:
# (1316, 11)

# %%
non_overlapping_df.shape
# Out:
# (4464, 11)

# %% [markdown]
# - Latency between the tone playing and the first port entry after the tone

# %%
overlapping_df["latency"].mean()
# Out:
# 12.819498098859215

# %%
non_overlapping_df["latency"].mean()
# Out:
# 12.618030475323993

# %% [markdown]
# - Latency between the tone playing and the first port entry after the tone. This had been adjusted so that all latencies that are greater than 30 seconds were adjusted to be just 30 seconds.

# %%
overlapping_df["latency_adjusted_greater_than_30"].mean()
# Out:
# 11.698623574144397

# %%
non_overlapping_df["latency_adjusted_greater_than_30"].mean()
# Out:
# 7.894318853763842

# %% [markdown]
# # Adjusting the Latencies if the Port Entries/Exit Overlap With the Tone Times

# %% [markdown]
# - For all the rows with overlapping last port entries before the tone, we will adjust the latency of the tone to the first port entry after the tone to 0. (Because the first port entry after the tone would be considered to be the same as the last port entry before the tone)

# %%
concatted_first_and_last_porty_entry_dataframe["latency_adjusted_overlap"] = concatted_first_and_last_porty_entry_dataframe.apply(lambda row: 0 if row["overlapping_port_entry_with_tone"] else row["latency_adjusted_greater_than_30"], axis=1)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        69.00
# 1             140.01                       148.27
# 2             230.01                       231.91
# 3             310.01                       320.97
# 4             385.01                       394.75
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        73.66
# 1                                       151.69
# 2                                       233.40
# 3                                       327.71
# 4                                       398.05
#
#                                            file_path      date  subject  \
# 0  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 1  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 2  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 3  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 4  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                        54.90                                        55.73
# 1                       125.14                                       126.71
# 2                       224.43                                       225.00
# 3                       298.91                                       299.28
# 4                       384.15                                       384.46
#
#    latency  latency_adjusted_greater_than_30  \
# 0     8.99                              8.99
# 1     8.26                              8.26
# 2     1.90                              1.90
# 3    10.96                             10.96
# 4     9.74                              9.74
#
#    overlapping_port_entry_with_tone  latency_adjusted_overlap
# 0                             False                      8.99
# 1                             False                      8.26
# 2                             False                      1.90
# 3                             False                     10.96
# 4                             False                      9.74

# %% [markdown]
# - All the rows with overlapping last port entries before the tone

# %%
concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"]].head()
# Out:
#     current_tone_time  first_port_entry_after_tone  \
# 21            1975.01                      1975.87
# 47             670.01                       670.27
# 53            1240.01                      1242.58
# 62            2055.01                      2067.11
# 63            2130.01                      2134.46
#
#     port_exit_after_first_port_entry_after_tone  \
# 21                                      1976.10
# 47                                       670.89
# 53                                      1243.36
# 62                                      2073.44
# 63                                      2134.66
#
#                                             file_path      date  subject  \
# 21  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 47  ./example_recordings/2022-05-06_08h37m_Subject...  20220506      2.3
# 53  ./example_recordings/2022-05-06_08h37m_Subject...  20220506      2.3
# 62  ./example_recordings/2022-05-06_08h37m_Subject...  20220506      2.3
# 63  ./example_recordings/2022-05-06_08h37m_Subject...  20220506      2.3
#
#     last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 21                      1973.96                                      1975.69
# 47                       669.88                                       670.17
# 53                      1239.45                                      1240.12
# 62                      2052.44                                      2055.04
# 63                      2129.20                                      2130.11
#
#     latency  latency_adjusted_greater_than_30  \
# 21     0.86                              0.86
# 47     0.26                              0.26
# 53     2.57                              2.57
# 62    12.10                             12.10
# 63     4.45                              4.45
#
#     overlapping_port_entry_with_tone  latency_adjusted_overlap
# 21                              True                       0.0
# 47                              True                       0.0
# 53                              True                       0.0
# 62                              True                       0.0
# 63                              True                       0.0

# %% [markdown]
# ## Labeling if a row's latency is less than 10 seconds or not

# %% [markdown]
# - We will be getting the ratio of latencies(from the time that the tone played, to the first port entry after the tone) that are less than 10 seconds for each session. So we will label all the adjusted latencies that are less than 10 seconds as `True`, and the those with latencies that are greater than 10 seconds as `False`

# %%
concatted_first_and_last_porty_entry_dataframe["adjusted_30_second_latency_less_than_10_seconds_ratio"] = concatted_first_and_last_porty_entry_dataframe["latency_adjusted_greater_than_30"].apply(lambda x: True if x <= 10 else False)

# %%
concatted_first_and_last_porty_entry_dataframe["overlap_adjusted_latency_less_than_10_seconds"] = concatted_first_and_last_porty_entry_dataframe["latency_adjusted_overlap"].apply(lambda x: True if x <= 10 else False)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        69.00
# 1             140.01                       148.27
# 2             230.01                       231.91
# 3             310.01                       320.97
# 4             385.01                       394.75
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        73.66
# 1                                       151.69
# 2                                       233.40
# 3                                       327.71
# 4                                       398.05
#
#                                            file_path      date  subject  \
# 0  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 1  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 2  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 3  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
# 4  ./example_recordings/2022-05-06_12h59m_Subject...  20220506  3.4 (2)
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                        54.90                                        55.73
# 1                       125.14                                       126.71
# 2                       224.43                                       225.00
# 3                       298.91                                       299.28
# 4                       384.15                                       384.46
#
#    latency  latency_adjusted_greater_than_30  \
# 0     8.99                              8.99
# 1     8.26                              8.26
# 2     1.90                              1.90
# 3    10.96                             10.96
# 4     9.74                              9.74
#
#    overlapping_port_entry_with_tone  latency_adjusted_overlap  \
# 0                             False                      8.99
# 1                             False                      8.26
# 2                             False                      1.90
# 3                             False                     10.96
# 4                             False                      9.74
#
#    adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                              False
# 4                                               True
#
#    overlap_adjusted_latency_less_than_10_seconds
# 0                                           True
# 1                                           True
# 2                                           True
# 3                                          False
# 4                                           True

# %% [markdown]
# # Making Dataframes that have Each Subject as the Row and Each Date as the Column

# %% [markdown]
# - Pivot plots allow us to make columns out of each unique entry in a selected column. (For this, it will be the date column that we will turn into columns) The index for the rows will be each unique entry in another column. (For this, it will be the subject's ID) And the values will be the aggregate of the values that have both the values in the previous two selected columns. (For this it will be the latency columns and we will take the mean)
#     - https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html

# %% [markdown]
# - Making a folder for all the pivotplots

# %% [markdown]
# # NOTE: If you decide to change the cage numbers or the dates used from the original ones from the imported dataframes, you will need to change the subsequent path to the cage number and dates you are using

# %%
first_port_entry_to_tone_latency_output_directory = "./proc/subject_rows_with_date_columns_dataframes/first_port_entry_to_tone_latency/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
first_port_entry_to_tone_latency_output_directory
# Out:
# './proc/subject_rows_with_date_columns_dataframes/first_port_entry_to_tone_latency/cage_1_2_3_4_date_20220504_20220512'

# %%
os.makedirs(first_port_entry_to_tone_latency_output_directory, exist_ok=True)

# %%
latencies_less_than_10_seconds_ratio_output_directory = "./proc/subject_rows_with_date_columns_dataframes/latencies_less_than_10_seconds_ratio/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
latencies_less_than_10_seconds_ratio_output_directory
# Out:
# './proc/subject_rows_with_date_columns_dataframes/latencies_less_than_10_seconds_ratio/cage_1_2_3_4_date_20220504_20220512'

# %%
os.makedirs(latencies_less_than_10_seconds_ratio_output_directory, exist_ok=True)

# %% [markdown]
# ## Making a pivot plot with the original latency

# %% [markdown]
# # TODO: Make new folders for each type

# %%
all_latency_pivot_plot = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='latency', \
                                        index=['subject'], columns=['date'], aggfunc=np.mean)

# %%
all_latency_pivot_plot.head()
# Out:
# date      20220504    20220505   20220506  20220507   20220508  20220509  \
# subject
# 1.1       6.046829   11.537750   5.956341   3.59800  10.863590   7.18400
# 1.2      25.471538   13.112195   7.628250   5.64800   4.987692   4.09525
# 1.3      36.300526  373.844750  14.234500   7.00100   8.922821   8.97225
# 1.4      10.832683  125.872000  29.977805  12.33400   6.594103   5.93475
# 2.1       7.548500   18.269268   5.618500   3.92925   6.335897   5.16775
#
# date     20220510  20220511  20220512
# subject
# 1.1      6.876750   9.92700       NaN
# 1.2      9.064000   6.92650  18.89000
# 1.3      8.345250   7.85100  16.60550
# 1.4      8.869625  19.38650       NaN
# 2.1      6.824000   4.94175  17.10825

# %% [markdown]
# - Getting the cage numbers for each subject and then making a dictionary out of it
#     - This will be used to add the cage information to the pivot plots

# %%
# Converting the cage numbers from floats to integers
# When the metadata is imported from the csv files, the cage number is imported as a float
metadata_df["cage"] = metadata_df["cage"].astype(int)

# %%
subject_to_cage = pd.Series(metadata_df["cage"].values,index=metadata_df["Subject"].values).to_dict()

# %%
subject_to_cage
# Out:
# {'3.4 (2)': 4,
#  '2.3': 1,
#  '4.3 (3)': 4,
#  '1.2': 2,
#  '1.1': 1,
#  '1.3': 2,
#  '2.4': 2,
#  '4.1 (1)': 3,
#  '4.4 (4)': 4,
#  '3.3 (4)': 3,
#  '3.2 (2)': 3,
#  '1.4': 1,
#  '3.1 (1)': 4,
#  '2.2': 1,
#  '2.1': 2,
#  '4.2 (3)': 3}

# %% [markdown]
# - Adding the cage information with the dictionary

# %%
all_latency_pivot_plot["cage"] = all_latency_pivot_plot.index.map(subject_to_cage)

# %%
all_latency_pivot_plot.head()
# Out:
# date      20220504    20220505   20220506  20220507   20220508  20220509  \
# subject
# 1.1       6.046829   11.537750   5.956341   3.59800  10.863590   7.18400
# 1.2      25.471538   13.112195   7.628250   5.64800   4.987692   4.09525
# 1.3      36.300526  373.844750  14.234500   7.00100   8.922821   8.97225
# 1.4      10.832683  125.872000  29.977805  12.33400   6.594103   5.93475
# 2.1       7.548500   18.269268   5.618500   3.92925   6.335897   5.16775
#
# date     20220510  20220511  20220512  cage
# subject
# 1.1      6.876750   9.92700       NaN     1
# 1.2      9.064000   6.92650  18.89000     2
# 1.3      8.345250   7.85100  16.60550     2
# 1.4      8.869625  19.38650       NaN     1
# 2.1      6.824000   4.94175  17.10825     2

# %%
os.path.join(first_port_entry_to_tone_latency_output_directory, "subject_to_date_original_latency_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date))
# Out:
# './proc/subject_rows_with_date_columns_dataframes/first_port_entry_to_tone_latency/cage_1_2_3_4_date_20220504_20220512/subject_to_date_original_latency_cage_1_2_3_4_date_20220504_20220512.csv'

# %%
all_latency_pivot_plot.to_csv(os.path.join(first_port_entry_to_tone_latency_output_directory, "subject_to_date_original_latency_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
all_latency_pivot_plot.to_excel(os.path.join(first_port_entry_to_tone_latency_output_directory, "subject_to_date_original_latency_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %% [markdown]
# ## Making a pivot plot with the latency that were greater than 30 seconds being adjusted

# %%
latency_greater_than_30_seconds_adjusted_pivot_plot = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='latency_adjusted_greater_than_30', index=['subject'],

                    columns=['date'], aggfunc=np.mean)

# %%
latency_greater_than_30_seconds_adjusted_pivot_plot["cage"] = latency_greater_than_30_seconds_adjusted_pivot_plot.index.map(subject_to_cage)

# %%
latency_greater_than_30_seconds_adjusted_pivot_plot.head()
# Out:
# date      20220504   20220505   20220506  20220507   20220508  20220509  \
# subject
# 1.1       6.046829   9.446750   5.956341   3.59800  10.670769   7.18400
# 1.2      17.573077  11.960732   7.628250   5.64800   4.987692   4.09525
# 1.3      21.131316  26.896000  10.405250   6.65950   8.282564   7.27000
# 1.4      10.832683  24.336000  12.144634   9.19425   6.594103   5.93475
# 2.1       7.473000  10.245122   5.289500   3.92925   5.700256   5.16775
#
# date     20220510  20220511  20220512  cage
# subject
# 1.1      6.862375   9.92350       NaN     1
# 1.2      7.562000   6.92650  16.95725     2
# 1.3      8.273500   7.78250  15.18050     2
# 1.4      8.779250  14.12675       NaN     1
# 2.1      6.824000   4.94175  15.18450     2

# %%
latency_greater_than_30_seconds_adjusted_pivot_plot.to_csv(os.path.join(first_port_entry_to_tone_latency_output_directory, "subject_to_date_latency_greater_than_30_seconds_adjusted_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
latency_greater_than_30_seconds_adjusted_pivot_plot.to_excel(os.path.join(first_port_entry_to_tone_latency_output_directory, "subject_to_date_latency_greater_than_30_seconds_adjusted_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %% [markdown]
# ## Making a pivot plot with adjusted latencies that overlapped with a tone playing

# %%
latency_that_overlaps_with_tone_adjusted_pivot_plot = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='latency_adjusted_overlap', index=['subject'],

                    columns=['date'], aggfunc=np.mean)

# %%
latency_that_overlaps_with_tone_adjusted_pivot_plot["cage"] = latency_that_overlaps_with_tone_adjusted_pivot_plot.index.map(subject_to_cage)

# %%
latency_that_overlaps_with_tone_adjusted_pivot_plot.head()
# Out:
# date      20220504   20220505   20220506  20220507  20220508  20220509  \
# subject
# 1.1       5.638780   8.474500   3.185366   1.96425  2.244872   1.64500
# 1.2      17.554615  10.497805   6.671250   4.24600  3.467436   2.48425
# 1.3      21.131316  26.146000   9.181750   3.99875  4.985128   3.83350
# 1.4      10.755366  24.336000  11.102683   6.52950  5.418974   3.51200
# 2.1       7.106250  10.013659   4.803500   2.69950  3.656410   1.60600
#
# date     20220510  20220511  20220512  cage
# subject
# 1.1      1.147125   0.66375       NaN     1
# 1.2      1.726750   2.05925   1.29275     2
# 1.3      2.830000   3.09475   1.14700     2
# 1.4      2.715875   4.73125       NaN     1
# 2.1      1.242750   2.20575   3.28225     2

# %%
latency_that_overlaps_with_tone_adjusted_pivot_plot.to_csv(os.path.join(first_port_entry_to_tone_latency_output_directory, "subject_to_date_latency_that_overlaps_with_tone_adjusted_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
latency_that_overlaps_with_tone_adjusted_pivot_plot.to_excel(os.path.join(first_port_entry_to_tone_latency_output_directory, "subject_to_date_latency_that_overlaps_with_tone_adjusted_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %% [markdown]
# ## Making a pivot plot with the ratio of original latencies that are less than 10 seconds

# %%
original_less_than_10_latency_df = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='adjusted_30_second_latency_less_than_10_seconds_ratio', index=['subject'],

                    columns=['date'], aggfunc=np.mean)

# %%
original_less_than_10_latency_df["cage"] = original_less_than_10_latency_df.index.map(subject_to_cage)

# %%
original_less_than_10_latency_df
# Out:
# date     20220504  20220505  20220506  20220507  20220508  20220509  20220510  \
# subject
# 1.1      0.780488  0.675000  0.829268     0.975  0.589744     0.725  0.687500
# 1.2      0.400000  0.487805  0.675000     0.925  0.923077     0.950  0.775000
# 1.3      0.225000  0.073171  0.600000     0.825  0.717949     0.700  0.725000
# 1.4      0.487805  0.025000  0.512195     0.600  0.769231     0.825  0.587500
# 2.1      0.775000  0.658537  0.875000     0.925  0.820513     0.775  0.600000
# 2.2      0.487805  0.750000  0.804878     0.925  0.820513     0.675  0.662500
# 2.3      0.487805  0.725000  0.902439     0.900  0.923077     0.925  0.837500
# 2.4      0.275000  0.536585  0.675000     0.850  0.923077     1.000  0.875000
# 3.1 (1)  0.780488  0.800000  0.825000     0.900  0.897436     0.950  0.853659
# 3.2 (2)  0.463415  0.585366  0.625000     0.650  0.400000     0.500  0.390244
# 3.3 (4)  0.536585  0.195122  0.525000     0.500  0.725000     0.650  0.682927
# 3.4 (2)  0.609756  0.800000  0.875000     0.775  0.897436     0.825  0.804878
# 4.1 (1)  0.195122  0.365854  0.525000     0.575  0.450000     0.475  0.560976
# 4.2 (3)  0.682927  0.292683  0.700000     0.575  0.875000     0.875  0.853659
# 4.3 (3)  0.829268  0.675000  0.725000     0.750  0.794872     0.825  0.731707
# 4.4 (4)  0.536585  0.525000  0.600000     0.475  0.794872     0.800  0.682927
#
# date     20220511  20220512  cage
# subject
# 1.1         0.500       NaN     1
# 1.2         0.800     0.325     2
# 1.3         0.700     0.450     2
# 1.4         0.425       NaN     1
# 2.1         0.775     0.400     2
# 2.2         0.300       NaN     1
# 2.3         0.750       NaN     1
# 2.4         0.900     0.800     2
# 3.1 (1)     0.925     0.925     4
# 3.2 (2)     0.525     0.575     3
# 3.3 (4)     0.450     0.550     3
# 3.4 (2)     0.850     0.800     4
# 4.1 (1)     0.625     0.375     3
# 4.2 (3)     0.825     0.725     3
# 4.3 (3)     0.750     0.850     4
# 4.4 (4)     0.825     0.850     4

# %%
original_less_than_10_latency_df.to_csv(os.path.join(latencies_less_than_10_seconds_ratio_output_directory, "subject_to_date_less_than_10_seconds_original_latencies_ratios_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
original_less_than_10_latency_df.to_excel(os.path.join(latencies_less_than_10_seconds_ratio_output_directory, "subject_to_date_less_than_10_seconds_original_latencies_ratios_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %% [markdown]
# ## Making a pivot plot with the ratio of overlap adjusted latencies that are less than 10 seconds

# %%
overlap_adjusted_less_than_10_latency_df = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='overlap_adjusted_latency_less_than_10_seconds', index=['subject'],

                    columns=['date'], aggfunc=np.mean)

# %%
overlap_adjusted_less_than_10_latency_df["cage"] = overlap_adjusted_less_than_10_latency_df.index.map(subject_to_cage)

# %%
overlap_adjusted_less_than_10_latency_df
# Out:
# date     20220504  20220505  20220506  20220507  20220508  20220509  20220510  \
# subject
# 1.1      0.780488  0.700000  0.926829     1.000  0.974359     0.975  1.000000
# 1.2      0.400000  0.560976  0.725000     0.950  0.974359     0.975  0.975000
# 1.3      0.225000  0.097561  0.650000     0.900  0.846154     0.825  0.950000
# 1.4      0.487805  0.025000  0.560976     0.725  0.794872     0.925  0.900000
# 2.1      0.775000  0.658537  0.875000     0.975  0.923077     1.000  1.000000
# 2.2      0.536585  0.775000  0.829268     0.975  1.000000     0.975  1.000000
# 2.3      0.487805  0.750000  0.926829     0.900  0.923077     0.950  0.987500
# 2.4      0.275000  0.560976  0.725000     0.875  0.948718     1.000  0.925000
# 3.1 (1)  0.804878  0.850000  0.900000     0.900  0.897436     0.950  0.902439
# 3.2 (2)  0.536585  0.634146  0.800000     0.875  0.800000     0.850  0.878049
# 3.3 (4)  0.585366  0.243902  0.575000     0.525  0.750000     0.675  0.756098
# 3.4 (2)  0.682927  0.825000  0.875000     0.825  0.923077     0.825  0.878049
# 4.1 (1)  0.195122  0.414634  0.550000     0.625  0.700000     0.825  0.682927
# 4.2 (3)  0.731707  0.292683  0.725000     0.600  0.875000     0.875  0.878049
# 4.3 (3)  0.829268  0.775000  0.750000     0.800  0.820513     0.825  0.731707
# 4.4 (4)  0.560976  0.525000  0.700000     0.600  0.846154     0.825  0.756098
#
# date     20220511  20220512  cage
# subject
# 1.1         1.000       NaN     1
# 1.2         1.000     0.975     2
# 1.3         0.950     0.975     2
# 1.4         0.850       NaN     1
# 2.1         0.975     0.900     2
# 2.2         0.825       NaN     1
# 2.3         0.950       NaN     1
# 2.4         0.975     0.975     2
# 3.1 (1)     0.950     1.000     4
# 3.2 (2)     0.900     0.825     3
# 3.3 (4)     0.475     0.625     3
# 3.4 (2)     0.950     0.975     4
# 4.1 (1)     0.700     0.425     3
# 4.2 (3)     0.825     0.750     3
# 4.3 (3)     0.800     0.850     4
# 4.4 (4)     0.825     0.900     4

# %%
overlap_adjusted_less_than_10_latency_df.to_csv(os.path.join(latencies_less_than_10_seconds_ratio_output_directory, "subject_to_date_less_than_10_seconds_overlap_adjusted_latencies_ratios_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
overlap_adjusted_less_than_10_latency_df.to_excel(os.path.join(latencies_less_than_10_seconds_ratio_output_directory, "subject_to_date_less_than_10_seconds_overlap_adjusted_latencies_ratios_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %% [markdown]
# # Plotting the latencies

# %% [markdown]
# ## Getting the averages for all the trials in one subject and one day

# %% [markdown]
# - We will plot a line for each subject. With the X-axis being the days since the first session. And the Y-axis is the latency values averaged across all the trials for one recording session
# - Grouping all the rows with the same subject and date(aka, all the trials in one session). And then getting the mean for each value

# %%
grouped_averaged_first_porty_entry_dataframe = concatted_first_and_last_porty_entry_dataframe.groupby(by=["file_path", "date", "subject"]).mean()

# %%
grouped_averaged_first_porty_entry_dataframe.head()
# Out:
#                                                                      current_tone_time  \
# file_path                                          date     subject
# ./example_recordings/2022-05-04_08h42m_Subject ... 20220504 1.1            1871.473415
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 1.4            1871.473415
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.2            1871.473415
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.3            1871.473415
# ./example_recordings/2022-05-04_10h11m_Subject ... 20220504 1.2            1825.635000
#
#                                                                      first_port_entry_after_tone  \
# file_path                                          date     subject
# ./example_recordings/2022-05-04_08h42m_Subject ... 20220504 1.1                      1877.520244
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 1.4                      1882.306098
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.2                      1886.697317
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.3                      1889.407561
# ./example_recordings/2022-05-04_10h11m_Subject ... 20220504 1.2                      1805.225128
#
#                                                                      port_exit_after_first_port_entry_after_tone  \
# file_path                                          date     subject
# ./example_recordings/2022-05-04_08h42m_Subject ... 20220504 1.1                                      1878.694634
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 1.4                                      1886.704634
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.2                                      1888.659756
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.3                                      1891.125122
# ./example_recordings/2022-05-04_10h11m_Subject ... 20220504 1.2                                      1807.875385
#
#                                                                      last_port_entry_before_tone  \
# file_path                                          date     subject
# ./example_recordings/2022-05-04_08h42m_Subject ... 20220504 1.1                      1863.806585
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 1.4                      1845.939756
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.2                      1852.594634
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.3                      1849.303659
# ./example_recordings/2022-05-04_10h11m_Subject ... 20220504 1.2                      1797.286750
#
#                                                                      port_exit_after_last_port_entry_before_tone  \
# file_path                                          date     subject
# ./example_recordings/2022-05-04_08h42m_Subject ... 20220504 1.1                                      1864.643659
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 1.4                                      1846.770488
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.2                                      1853.810732
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.3                                      1850.358780
# ./example_recordings/2022-05-04_10h11m_Subject ... 20220504 1.2                                      1799.368000
#
#                                                                        latency  \
# file_path                                          date     subject
# ./example_recordings/2022-05-04_08h42m_Subject ... 20220504 1.1       6.046829
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 1.4      10.832683
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.2      15.223902
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.3      17.934146
# ./example_recordings/2022-05-04_10h11m_Subject ... 20220504 1.2      25.471538
#
#                                                                      latency_adjusted_greater_than_30  \
# file_path                                          date     subject
# ./example_recordings/2022-05-04_08h42m_Subject ... 20220504 1.1                              6.046829
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 1.4                             10.832683
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.2                             11.941707
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.3                             12.924146
# ./example_recordings/2022-05-04_10h11m_Subject ... 20220504 1.2                             17.573077
#
#                                                                      overlapping_port_entry_with_tone  \
# file_path                                          date     subject
# ./example_recordings/2022-05-04_08h42m_Subject ... 20220504 1.1                              0.170732
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 1.4                              0.024390
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.2                              0.170732
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.3                              0.073171
# ./example_recordings/2022-05-04_10h11m_Subject ... 20220504 1.2                              0.025000
#
#                                                                      latency_adjusted_overlap  \
# file_path                                          date     subject
# ./example_recordings/2022-05-04_08h42m_Subject ... 20220504 1.1                      5.638780
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 1.4                     10.755366
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.2                     10.842927
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.3                     12.689512
# ./example_recordings/2022-05-04_10h11m_Subject ... 20220504 1.2                     17.554615
#
#                                                                      adjusted_30_second_latency_less_than_10_seconds_ratio  \
# file_path                                          date     subject
# ./example_recordings/2022-05-04_08h42m_Subject ... 20220504 1.1                                               0.780488
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 1.4                                               0.487805
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.2                                               0.487805
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.3                                               0.487805
# ./example_recordings/2022-05-04_10h11m_Subject ... 20220504 1.2                                               0.400000
#
#                                                                      overlap_adjusted_latency_less_than_10_seconds
# file_path                                          date     subject
# ./example_recordings/2022-05-04_08h42m_Subject ... 20220504 1.1                                           0.780488
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 1.4                                           0.487805
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.2                                           0.536585
# ./example_recordings/2022-05-04_08h43m_Subject ... 20220504 2.3                                           0.487805
# ./example_recordings/2022-05-04_10h11m_Subject ... 20220504 1.2                                           0.400000

# %% [markdown]
# ## Reformatting the Dataframe for plotting

# %% [markdown]
# - Resetting the index so that we can use the data as a value

# %%
grouped_averaged_first_porty_entry_dataframe = grouped_averaged_first_porty_entry_dataframe.reset_index()

# %%
grouped_averaged_first_porty_entry_dataframe.head()
# Out:
#                                            file_path      date subject  \
# 0  ./example_recordings/2022-05-04_08h42m_Subject...  20220504     1.1
# 1  ./example_recordings/2022-05-04_08h43m_Subject...  20220504     1.4
# 2  ./example_recordings/2022-05-04_08h43m_Subject...  20220504     2.2
# 3  ./example_recordings/2022-05-04_08h43m_Subject...  20220504     2.3
# 4  ./example_recordings/2022-05-04_10h11m_Subject...  20220504     1.2
#
#    current_tone_time  first_port_entry_after_tone  \
# 0        1871.473415                  1877.520244
# 1        1871.473415                  1882.306098
# 2        1871.473415                  1886.697317
# 3        1871.473415                  1889.407561
# 4        1825.635000                  1805.225128
#
#    port_exit_after_first_port_entry_after_tone  last_port_entry_before_tone  \
# 0                                  1878.694634                  1863.806585
# 1                                  1886.704634                  1845.939756
# 2                                  1888.659756                  1852.594634
# 3                                  1891.125122                  1849.303659
# 4                                  1807.875385                  1797.286750
#
#    port_exit_after_last_port_entry_before_tone    latency  \
# 0                                  1864.643659   6.046829
# 1                                  1846.770488  10.832683
# 2                                  1853.810732  15.223902
# 3                                  1850.358780  17.934146
# 4                                  1799.368000  25.471538
#
#    latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# 0                          6.046829                          0.170732
# 1                         10.832683                          0.024390
# 2                         11.941707                          0.170732
# 3                         12.924146                          0.073171
# 4                         17.573077                          0.025000
#
#    latency_adjusted_overlap  \
# 0                  5.638780
# 1                 10.755366
# 2                 10.842927
# 3                 12.689512
# 4                 17.554615
#
#    adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                           0.780488
# 1                                           0.487805
# 2                                           0.487805
# 3                                           0.487805
# 4                                           0.400000
#
#    overlap_adjusted_latency_less_than_10_seconds
# 0                                       0.780488
# 1                                       0.487805
# 2                                       0.536585
# 3                                       0.487805
# 4                                       0.400000

# %% [markdown]
# - Turning the date column which is a string, into an integer
#     - This will allow us to use the date as the X-axis for plotting

# %%
grouped_averaged_first_porty_entry_dataframe["date_int"] = grouped_averaged_first_porty_entry_dataframe["date"].astype(int)

# %%
grouped_averaged_first_porty_entry_dataframe.head()
# Out:
#                                            file_path      date subject  \
# 0  ./example_recordings/2022-05-04_08h42m_Subject...  20220504     1.1
# 1  ./example_recordings/2022-05-04_08h43m_Subject...  20220504     1.4
# 2  ./example_recordings/2022-05-04_08h43m_Subject...  20220504     2.2
# 3  ./example_recordings/2022-05-04_08h43m_Subject...  20220504     2.3
# 4  ./example_recordings/2022-05-04_10h11m_Subject...  20220504     1.2
#
#    current_tone_time  first_port_entry_after_tone  \
# 0        1871.473415                  1877.520244
# 1        1871.473415                  1882.306098
# 2        1871.473415                  1886.697317
# 3        1871.473415                  1889.407561
# 4        1825.635000                  1805.225128
#
#    port_exit_after_first_port_entry_after_tone  last_port_entry_before_tone  \
# 0                                  1878.694634                  1863.806585
# 1                                  1886.704634                  1845.939756
# 2                                  1888.659756                  1852.594634
# 3                                  1891.125122                  1849.303659
# 4                                  1807.875385                  1797.286750
#
#    port_exit_after_last_port_entry_before_tone    latency  \
# 0                                  1864.643659   6.046829
# 1                                  1846.770488  10.832683
# 2                                  1853.810732  15.223902
# 3                                  1850.358780  17.934146
# 4                                  1799.368000  25.471538
#
#    latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# 0                          6.046829                          0.170732
# 1                         10.832683                          0.024390
# 2                         11.941707                          0.170732
# 3                         12.924146                          0.073171
# 4                         17.573077                          0.025000
#
#    latency_adjusted_overlap  \
# 0                  5.638780
# 1                 10.755366
# 2                 10.842927
# 3                 12.689512
# 4                 17.554615
#
#    adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                           0.780488
# 1                                           0.487805
# 2                                           0.487805
# 3                                           0.487805
# 4                                           0.400000
#
#    overlap_adjusted_latency_less_than_10_seconds  date_int
# 0                                       0.780488  20220504
# 1                                       0.487805  20220504
# 2                                       0.536585  20220504
# 3                                       0.487805  20220504
# 4                                       0.400000  20220504

# %% [markdown]
# - Adding the cage information
#     - We will make one plot for each cage

# %%
grouped_averaged_first_porty_entry_dataframe["cage"] = grouped_averaged_first_porty_entry_dataframe["subject"].map(subject_to_cage).astype(int)

# %%
grouped_averaged_first_porty_entry_dataframe.head()
# Out:
#                                            file_path      date subject  \
# 0  ./example_recordings/2022-05-04_08h42m_Subject...  20220504     1.1
# 1  ./example_recordings/2022-05-04_08h43m_Subject...  20220504     1.4
# 2  ./example_recordings/2022-05-04_08h43m_Subject...  20220504     2.2
# 3  ./example_recordings/2022-05-04_08h43m_Subject...  20220504     2.3
# 4  ./example_recordings/2022-05-04_10h11m_Subject...  20220504     1.2
#
#    current_tone_time  first_port_entry_after_tone  \
# 0        1871.473415                  1877.520244
# 1        1871.473415                  1882.306098
# 2        1871.473415                  1886.697317
# 3        1871.473415                  1889.407561
# 4        1825.635000                  1805.225128
#
#    port_exit_after_first_port_entry_after_tone  last_port_entry_before_tone  \
# 0                                  1878.694634                  1863.806585
# 1                                  1886.704634                  1845.939756
# 2                                  1888.659756                  1852.594634
# 3                                  1891.125122                  1849.303659
# 4                                  1807.875385                  1797.286750
#
#    port_exit_after_last_port_entry_before_tone    latency  \
# 0                                  1864.643659   6.046829
# 1                                  1846.770488  10.832683
# 2                                  1853.810732  15.223902
# 3                                  1850.358780  17.934146
# 4                                  1799.368000  25.471538
#
#    latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# 0                          6.046829                          0.170732
# 1                         10.832683                          0.024390
# 2                         11.941707                          0.170732
# 3                         12.924146                          0.073171
# 4                         17.573077                          0.025000
#
#    latency_adjusted_overlap  \
# 0                  5.638780
# 1                 10.755366
# 2                 10.842927
# 3                 12.689512
# 4                 17.554615
#
#    adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                           0.780488
# 1                                           0.487805
# 2                                           0.487805
# 3                                           0.487805
# 4                                           0.400000
#
#    overlap_adjusted_latency_less_than_10_seconds  date_int  cage
# 0                                       0.780488  20220504     1
# 1                                       0.487805  20220504     1
# 2                                       0.536585  20220504     1
# 3                                       0.487805  20220504     1
# 4                                       0.400000  20220504     2

# %% [markdown]
# ## Plotting the latencies that were adjusted if they greater than 30 seconds

# %%
original_average_latency_output_directory = "./proc/plots/original_average_latency_plots/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
original_average_latency_output_directory
# Out:
# './proc/plots/original_average_latency_plots/cage_1_2_3_4_date_20220504_20220512'

# %%
os.makedirs(original_average_latency_output_directory, exist_ok=True)

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["date_int"] - subject_df["date_int"].min() + 1, subject_df["latency_adjusted_greater_than_30"], '-o', label=subject)

    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 30)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("The Days After the First Session")
    ax.set_ylabel("Adjusted Average Latency of First Entry to Tone Onset")
    ax.set_title("Latency of Port Entry to Tone: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    file_name = "original_average_latency_plot_cage_{}_date_{}_{}.png".format(cage, earliest_date, latest_date)
    plt.savefig(os.path.join(original_average_latency_output_directory, file_name))

# %% [markdown]
# ## Plotting the original ratio of latencies that are less than 10 seconds

# %%
less_than_10_second_original_latency_ratio_plots_output_directory = "./proc/plots/less_than_10_second_original_latency_ratio/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
less_than_10_second_original_latency_ratio_plots_output_directory
# Out:
# './proc/plots/less_than_10_second_original_latency_ratio/cage_1_2_3_4_date_20220504_20220512'

# %%
os.makedirs(less_than_10_second_original_latency_ratio_plots_output_directory, exist_ok=True)

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["date_int"] - subject_df["date_int"].min() + 1, subject_df["adjusted_30_second_latency_less_than_10_seconds_ratio"], '-o', label=subject)
    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 1)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("The Days After the First Session")
    ax.set_ylabel("Proportion of Latencies")
    ax.set_title("Less Than 10 Seconds Latencies from Tone Onset: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    
    file_name = "less_than_10_second_original_latency_ratio_plot_cage_{}_date_{}_{}.png".format(cage, earliest_date, latest_date)
    plt.savefig(os.path.join(less_than_10_second_original_latency_ratio_plots_output_directory, file_name))

# %% [markdown]
# # Plotting the Adjusted Latencies for Entries that Overlap with the Tone

# %% [markdown]
# ## Plotting the Latencies

# %%
overlap_adjusted_average_latency_plots_output_directory = "./proc/plots/overlap_adjusted_average_latency_plots/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
overlap_adjusted_average_latency_plots_output_directory
# Out:
# './proc/plots/overlap_adjusted_average_latency_plots/cage_1_2_3_4_date_20220504_20220512'

# %%
os.makedirs(overlap_adjusted_average_latency_plots_output_directory, exist_ok=True)

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["date_int"] - subject_df["date_int"].min() + 1, subject_df["latency_adjusted_overlap"], '-o', label=subject)

    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 30)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("The Days After the First Session")
    ax.set_ylabel("Proportion of Latencies")
    ax.set_title("Overlap Adjusted Latency of Port Entry to Tone: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    file_name = "overlap_adjusted_average_latency_plot_cage_{}_date_{}_{}.png".format(cage, earliest_date, latest_date)

    plt.savefig(os.path.join(overlap_adjusted_average_latency_plots_output_directory, file_name))

# %% [markdown]
# # Plotting the ratio of overlap adjusted latencies that are less than 10 seconds

# %%
less_than_10_second_overlap_adjusted_latency_ratio_output_directory = "./proc/plots/less_than_10_second_overlap_adjusted_latency_ratio/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
less_than_10_second_overlap_adjusted_latency_ratio_output_directory
# Out:
# './proc/plots/less_than_10_second_overlap_adjusted_latency_ratio/cage_1_2_3_4_date_20220504_20220512'

# %%
os.makedirs(less_than_10_second_overlap_adjusted_latency_ratio_output_directory, exist_ok=True)

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["date_int"] - subject_df["date_int"].min() + 1, subject_df["overlap_adjusted_latency_less_than_10_seconds"], '-o', label=subject)

    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 1)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("The Days After the First Session")
    ax.set_ylabel("Proportion of Latencies")
    ax.set_title("Overlap Adjusted Less Than 10sec Latencies from Tone: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    
    file_name = "less_than_10_second_overlap_adjusted_latency_ratio_plot_cage{}_date_{}_{}.png".format(cage, earliest_date, latest_date)
    plt.savefig(os.path.join(less_than_10_second_overlap_adjusted_latency_ratio_output_directory, file_name))
